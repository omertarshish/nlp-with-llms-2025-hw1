# %% [markdown]
# # POS Tagger Trained on the UD Treebank

# %% [markdown]
# Adapted from https://github.com/soutsios/pos_tagger_mlp/blob/master/pos_tagger_mlp.ipynb

# %%
import pyconll, nltk, datetime, warnings
import numpy as np
from scipy.sparse import vstack
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import StratifiedKFold, GridSearchCV, learning_curve
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings(action='ignore', category=UndefinedMetricWarning)
from numpy.random import seed

# %% [markdown]
# # Plot Functions
#
# These functions are useful to visualize the training dynamics of the learning algorithm and the confusion matrix of the trained models.

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=None, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Accuracy")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring='accuracy')
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
def plot_confusion_matrix(f1,
                          cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True,
                          i=1):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    plt.figure(figsize=(10, 6))
    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}; f1-score={:0.4f}'.format(accuracy, misclass, f1))

# %% [markdown]
# # Load Dataset

# %%
UD_ENGLISH_TRAIN = '../UD_English-EWT/en_ewt-ud-train.conllu'
UD_ENGLISH_DEV = '../UD_English-EWT/en_ewt-ud-dev.conllu'
UD_ENGLISH_TEST = '../UD_English-EWT/en_ewt-ud-test.conllu'

# %% [markdown]
# # Preprocessing

# %%
def read_conllu(path):
    data = pyconll.load_from_file(path)
    tagged_sentences=[]
    original_sentences=[]
    t=0
    for sentence in data:
        original_sentences.append(sentence.text)
        tagged_sentence=[]
        for token in sentence:
            if token.upos:
                t+=1
                tagged_sentence.append((token.form if token.form else '*None*', token.upos))
        tagged_sentences.append(tagged_sentence)
    return tagged_sentences, original_sentences

# %% [markdown]
# Load train, development and test set in the appropriate tagged format, tuple (word, pos-tag)

# %%
train_sentences, train_original = read_conllu(UD_ENGLISH_TRAIN)
val_sentences, val_original = read_conllu(UD_ENGLISH_DEV)
test_sentences, test_original = read_conllu(UD_ENGLISH_TEST)

# %% [markdown]
# Print statistics

# %%
print("Tagged sentences in train set: ", len(train_sentences))
print("Tagged words in train set:", len([item for sublist in train_sentences for item in sublist]))
print(40*'=')
print("Tagged sentences in dev set: ", len(val_sentences))
print("Tagged words in dev set:", len([item for sublist in val_sentences for item in sublist]))
print(40*'=')
print("Tagged sentences in test set: ", len(test_sentences))
print("Tagged words in test set:", len([item for sublist in test_sentences for item in sublist]))
# Out:
# Tagged sentences in train set:  12544
# Tagged words in train set: 204614
# ========================================
# Tagged sentences in dev set:  2001
# Tagged words in dev set: 25151
# ========================================
# Tagged sentences in test set:  2077
# Tagged words in test set: 25096

# %%
print(train_sentences[0])
# Out:
# [('Al', 'PROPN'), ('-', 'PUNCT'), ('Zaman', 'PROPN'), (':', 'PUNCT'), ('American', 'ADJ'), ('forces', 'NOUN'), ('killed', 'VERB'), ('Shaikh', 'PROPN'), ('Abdullah', 'PROPN'), ('al', 'PROPN'), ('-', 'PUNCT'), ('Ani', 'PROPN'), (',', 'PUNCT'), ('the', 'DET'), ('preacher', 'NOUN'), ('at', 'ADP'), ('the', 'DET'), ('mosque', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('town', 'NOUN'), ('of', 'ADP'), ('Qaim', 'PROPN'), (',', 'PUNCT'), ('near', 'ADP'), ('the', 'DET'), ('Syrian', 'ADJ'), ('border', 'NOUN'), ('.', 'PUNCT')]

# %%
def tag_sequence(sentences):
    return [[t for w, t in sentence] for sentence in sentences]

def text_sequence(sentences):
    return [[w for w, t in sentence] for sentence in sentences]

def id2word(sentences):
    wordlist = [item for sublist in text_sequence(sentences) for item in sublist]
    id2word = {k:v for k,v in enumerate(wordlist)}
    return id2word

def untag(tagged_sentence):
    return [w for w, _ in tagged_sentence]

def untag_pos(tagged_sentence):
    return [t for _, t in tagged_sentence]

def build_vocab(sentences):
    vocab =set()
    for sentence in sentences:
        for word in untag(sentence):
            vocab.add(word)
    return sorted(list(vocab))

# %% [markdown]
# An important observation: how many terms are in validation set and not found in train set? (This estimates the Out-of-vocabulary rate.)

# %%
list_1 = build_vocab(train_sentences)
list_2 = build_vocab(val_sentences)
diff_list = [item for item in list_2 if item not in list_1]
print('Number of terms not found in train set:',len(diff_list))
# Out:
# Number of terms not found in train set: 1662

# %% [markdown]
# # Feature Engineering
#
# We use the "classical" machine learning approach: we will train a token classifier model. The classifier gets as input a feature vector describing each token in the sentence. We decide a priori which features are informative to make the tagging decision. In this case, we use a combination of "word shape" features which approximate morphological knowledge. We naturally also include lexical information (the token form itself), and some form of "syntactic knowledge" by adding reference to the previous and next word in each token feature vector.

# %%
def features_basic(sentence, index):
    """ sentence: [w1, w2, ...], index: the index of the word """
    return {
        'nb_terms': len(sentence),        
        'word': sentence[index],
        'word_lower': sentence[index].lower(),
        'is_first': index == 0,
        'is_last': index == len(sentence) - 1,
        'is_capitalized': sentence[index][0].upper() == sentence[index][0],
        'is_all_caps': sentence[index].upper() == sentence[index],
        'is_all_lower': sentence[index].lower() == sentence[index],
        'prefix-1': sentence[index][0],
        'prefix-2': sentence[index][:2],
        'prefix-3': sentence[index][:3],
        'suffix-1': sentence[index][-1],
        'suffix-2': sentence[index][-2:],
        'suffix-3': sentence[index][-3:],
        'i-1_prefix-3': '' if index == 0 else sentence[index-1][:3],        
        'i-1_suffix-3': '' if index == 0 else sentence[index-1][-3:],        
        'i+1_prefix-3': '' if index == len(sentence) - 1 else sentence[index+1][:3],        
        'i+1_suffix-3': '' if index == len(sentence) - 1 else sentence[index+1][-3:],        
        'prev_word': '' if index == 0 else sentence[index - 1].lower(),
        'next_word': '' if index == len(sentence) - 1 else sentence[index + 1].lower(),
        'has_hyphen': '-' in sentence[index],
        'is_numeric': sentence[index].isdigit(),
        'capitals_inside': sentence[index][1:].lower() != sentence[index][1:],
    }

# %% [markdown]
# In the scikit-learn model, we model a dataset as a pair of two data structures:
# * The list of feature dictionaries X (one feature dictionary for each token)
# * The list of predicted label y (one tag for each token)

# %%
def transform_to_dataset(tagged_sentences):
    X, y = [], []
    for doc_index, tagged in enumerate(tagged_sentences):
        for index in range(len(tagged)):
            X.append([features_basic(untag(tagged), index)])
            y.append(tagged[index][1])
    return X, y

# %% [markdown]
# Given a sentence represented as a list of tokens, return the list of feature dictionaries using our feature encoding method:

# %%
def transform_test_sentence(sentence):
    X = []
    for index in range(len(sentence)):
            X.append([features_basic(sentence, index)])
    return X

# %% [markdown]
# ## Test untag()
#
# We use untag() to extract raw sentences from the annotated CoNLL dataset. This way we can reproduce a sentence without tags, submit it to the tagger and compare predictions to the gold tags that are provided in the dataset.

# %%
untag(test_sentences[1])
# Out:
# ['What',
#  'if',
#  'Google',
#  'expanded',
#  'on',
#  'its',
#  'search',
#  '-',
#  'engine',
#  '(',
#  'and',
#  'now',
#  'e-mail',
#  ')',
#  'wares',
#  'into',
#  'a',
#  'full',
#  '-',
#  'fledged',
#  'operating',
#  'system',
#  '?']

# %% [markdown]
# # Dataset Transformation

# %% [markdown]
# Before we can apply a generic machine learning algorithm (such as Logistic Regression), we need to encode the dataset into a vectorized format.
#
# We proceed in two steps: feature engineering and vectorization.
#
# For each token, we create a dictionary of features that depend on the sentence from which the token is extracted.
# These features include the word itself, the word before and the word after, letter suffixes and prefixes, etc.
#
# In the scikit-learn approach, before we can use a generic machine learning algorithm, we must then "vectorize" the feature dictionaries into vector encodings.
# For example, lexical features are encoded into one-hot vectors whose dimension is the size of the vocabulary.
# Note the difference between the method `fit_transform` of the vectorizer, which "learns" how to vectorize features, and `transform` which applies a learned vectorizer to feature dictionaries.  We use `fit_transform` on the training data, and `transform` on the other sections (validation and test).
#
# These vector representations are what is passed to the machine learning algorithm.

# %%
def vectorize(train, val, test):

    print('Feature encoding method')
    print('Vectorizing Dataset...')
    print('Vectorizing train...')
    X_train, y_train = transform_to_dataset(train)
    v = DictVectorizer(sparse=True) 
    X_train = v.fit_transform([x[0] for x in X_train])
    
    print('Vectorizing validation...')
    X_val, y_val = transform_to_dataset(val)
    X_val = v.transform([x[0] for x in X_val])        
    
    print('Vectorizing test...')
    X_test, y_test = transform_to_dataset(test)
    X_test = v.transform([x[0] for x in X_test])
    
    print('Dataset vectorized.')
    print('Train shape:', X_train.shape)
    print('Validation shape:', X_val.shape)
    print('Test shape:', X_test.shape)
    
    # Compress sparse matrices
    X_train = X_train 
    X_val = X_val 
    X_test = X_test
    return X_train, y_train, X_val, y_val, X_test, y_test, v

# %% [markdown]
# # Baseline Tagger

# %% [markdown]
# Before we train a "real" machine learning algorithm using scikit-learn, we will repeat the very simple statistical method we discussed in class.
# We train and evaluate the Baseline Unigram tagger to compare performance with the tagger we will train next.

# %%
default_tagger = nltk.DefaultTagger('NOUN')
unigram_tagger = nltk.UnigramTagger(train_sentences+val_sentences, backoff=default_tagger)

# %%
y_train = [item for sublist in tag_sequence(train_sentences+val_sentences) for item in sublist]
y_test = [item for sublist in tag_sequence(test_sentences) for item in sublist]
classes = sorted(list(set(y_train)))

# %%
def tag_list(tagged_sents):
    return [tag for sent in tagged_sents for (word, tag) in sent]
def apply_tagger(tagger, corpus):
    return [tagger.tag(nltk.tag.untag(sent)) for sent in corpus]

# %%
y_pred = tag_list(apply_tagger(unigram_tagger, test_sentences))
print("Accuracy: {0:.4f}".format(unigram_tagger.accuracy(test_sentences)))
print('f1-macro score: {0:.4f}'.format(f1_score(y_test, y_pred, zero_division=1, average='macro')))
# Out:
# Accuracy: 0.8670
# f1-macro score: 0.7959

# %%
print(classification_report(y_test, y_pred, zero_division=1, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#          ADJ     0.9154    0.8356    0.8737      1788
#          ADP     0.8697    0.8817    0.8757      2029
#          ADV     0.9355    0.8044    0.8650      1191
#          AUX     0.9233    0.8970    0.9099      1543
#        CCONJ     0.9892    0.9973    0.9932       736
#          DET     0.9612    0.9673    0.9643      1897
#         INTJ     0.9655    0.6942    0.8077       121
#         NOUN     0.6878    0.9323    0.7916      4123
#          NUM     0.9146    0.6125    0.7337       542
#         PART     0.6959    0.9769    0.8128       649
#         PRON     0.9660    0.9321    0.9488      2165
#        PROPN     0.9240    0.5446    0.6853      2075
#        PUNCT     0.9941    0.9861    0.9901      3096
#        SCONJ     0.6257    0.5964    0.6107       384
#          SYM     0.7913    0.8349    0.8125       109
#         VERB     0.8880    0.8243    0.8549      2606
#            X     1.0000    0.0000    0.0000        42
#
#     accuracy                         0.8670     25096
#    macro avg     0.8851    0.7834    0.7959     25096
# weighted avg     0.8830    0.8670    0.8652     25096

# %% [markdown]
# See what errors the Baseline tagger makes:

# %%
def check_tagger(tagged_sentence):
    note = ''
    for tup in list(zip(unigram_tagger.tag(untag(tagged_sentence)),untag_pos(tagged_sentence))):
        if tup[0][1]!=tup[1]: note='<<--- Error!'
        print(tup[0], tup[1], note)
        note=''

# %%
check_tagger(test_sentences[1])
# Out:
# ('What', 'PRON') PRON
# ('if', 'SCONJ') SCONJ
# ('Google', 'PROPN') PROPN
# ('expanded', 'VERB') VERB
# ('on', 'ADP') ADP
# ('its', 'PRON') PRON
# ('search', 'NOUN') NOUN
# ('-', 'PUNCT') PUNCT
# ('engine', 'NOUN') NOUN
# ('(', 'PUNCT') PUNCT
# ('and', 'CCONJ') CCONJ
# ('now', 'ADV') ADV
# ('e-mail', 'NOUN') NOUN
# (')', 'PUNCT') PUNCT
# ('wares', 'NOUN') NOUN
# ('into', 'ADP') ADP
# ('a', 'DET') DET
# ('full', 'ADJ') ADV <<--- Error!
# ('-', 'PUNCT') PUNCT
# ('fledged', 'NOUN') ADJ <<--- Error!
# ('operating', 'NOUN') NOUN
# ('system', 'NOUN') NOUN
# ('?', 'PUNCT') PUNCT

# %% [markdown]
# It makes mistakes. Unsurprising given its simplistic approach and the small size of the training data.

# %%
cnf_matrix = confusion_matrix(y_test, y_pred)
name='Baseline'

# %%
plot_confusion_matrix(f1_score(y_test, y_pred, average='macro'), cnf_matrix, target_names=classes, title='Confusion matrix for '+name+' classifier', normalize=False)

# %% [markdown]
# # Train a Logistic Regression Model

# %% [markdown]
# Let us move to a more serious machine learning model. We will train a Logistic Regression model using our feature extraction function based on our "expertise" in the domain.
#
# We first transform the whole dataset from the CoNLL format into the scikit-learn vectorized encoding using our feature extraction method.

# %%
X_train, y_train, X_val, y_val, X_test, y_test, vec = vectorize(train_sentences, val_sentences, test_sentences)
# Out:
# Feature encoding method
# Vectorizing Dataset...
# Vectorizing train...
# Vectorizing validation...
# Vectorizing test...
# Dataset vectorized.
# Train shape: (204614, 98719)
# Validation shape: (25151, 98719)
# Test shape: (25096, 98719)

# %% [markdown]
# ## Hyper-parameter Tuning

# %% [markdown]
# The Logistic Regression algorithm uses a hyper-parameter called C.  We tune the value of this parameter by testing different values on a subset of the training data and observing the impact of the C parameter on selected metrics (accuracy and F1).
#
# Because we will use cross-validation, we can use the full train set (train + validation)

# %%
X_train = vstack((X_train, X_val))
y_train = np.append(y_train, y_val, axis=0)

# %%
X_train.shape
# Out:
# (229765, 98719)

# %%
y_train.shape
# Out:
# (229765,)

# %%
def hyper_tuning(train, test, y_train, y_test, scores, estimator, parameters, cv):
    print("# Estimator:",estimator)
    for score in scores:
        print("# Tuning hyper-parameters for %s" % score)        
        clf = GridSearchCV(estimator, parameters, cv=cv, scoring='%s' % score)
        clf.fit(train, y_train)
        print("Best parameters set found on development set:")
        print(clf.best_params_)
        print()
        print("Grid scores on development set:")
        means = clf.cv_results_['mean_test_score']
        stds = clf.cv_results_['std_test_score']
        for mean, std, params in zip(means, stds, clf.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
        print()
        print("Detailed classification report:")
        print("The model is trained on the full development set.")
        print("The scores are computed on the full evaluation set.")
        y_pred = clf.predict(test)
        print(classification_report(y_test, y_pred, digits=4))
        print('Accuracy: {0:0.4f}   f1-score: {1:0.4f} \n'.format(accuracy_score(y_test, y_pred), f1_score(y_test, y_pred, average='macro')))
    return clf

# %%
logregr = LogisticRegression(solver='liblinear', random_state=13)
# Cross validation strategy
skf = StratifiedKFold(n_splits=4)
# Scores could also be ['precision', 'recall', ....]
scores = ['accuracy', 'f1_macro']

params = [{'C': [0.1, 1, 2, 3, 4, 5, 10, 20, 50]}]
#logregr = hyper_tuning(X_train, X_test, y_train, y_test, scores, logregr, params, skf)
#You may want to comment previous line and comment-out next lines to see how hyper-tuning works and dont wait too much time...
skf = StratifiedKFold(n_splits=4)
logregr = hyper_tuning(X_train[:500], X_test[:50], y_train[:500], y_test[:50], scores, logregr, params, skf)
# Out:
# # Estimator: LogisticRegression(random_state=13, solver='liblinear')
# # Tuning hyper-parameters for accuracy
# Best parameters set found on development set:
# {'C': 20}
#
# Grid scores on development set:
# 0.748 (+/-0.027) for {'C': 0.1}
# 0.828 (+/-0.046) for {'C': 1}
# 0.834 (+/-0.041) for {'C': 2}
# 0.836 (+/-0.035) for {'C': 3}
# 0.836 (+/-0.035) for {'C': 4}
# 0.838 (+/-0.029) for {'C': 5}
# 0.842 (+/-0.033) for {'C': 10}
# 0.846 (+/-0.035) for {'C': 20}
# 0.844 (+/-0.042) for {'C': 50}
#
# Detailed classification report:
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#          ADJ     0.0000    0.0000    0.0000         1
#          ADP     1.0000    0.6667    0.8000         6
#          ADV     0.0000    0.0000    0.0000         4
#          AUX     1.0000    1.0000    1.0000         1
#        CCONJ     1.0000    0.5000    0.6667         2
#          DET     0.6667    1.0000    0.8000         2
#         NOUN     0.6667    0.8571    0.7500         7
#         PRON     1.0000    0.2500    0.4000         4
#        PROPN     0.6667    1.0000    0.8000         8
#        PUNCT     1.0000    1.0000    1.0000        11
#        SCONJ     1.0000    1.0000    1.0000         2
#         VERB     0.2000    0.5000    0.2857         2
#
#     accuracy                         0.7400        50
#    macro avg     0.6833    0.6478    0.6252        50
# weighted avg     0.7547    0.7400    0.7111        50
#
# Accuracy: 0.7400   f1-score: 0.6252
#
# # Tuning hyper-parameters for f1_macro
# Best parameters set found on development set:
# {'C': 20}
#
# Grid scores on development set:
# 0.515 (+/-0.041) for {'C': 0.1}
# 0.657 (+/-0.140) for {'C': 1}
# 0.667 (+/-0.129) for {'C': 2}
# 0.676 (+/-0.107) for {'C': 3}
# 0.676 (+/-0.107) for {'C': 4}
# 0.681 (+/-0.096) for {'C': 5}
# 0.694 (+/-0.100) for {'C': 10}
# 0.718 (+/-0.110) for {'C': 20}
# 0.717 (+/-0.113) for {'C': 50}
#
# Detailed classification report:
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#               precision    recall  f1-score   support
#
#          ADJ     0.0000    0.0000    0.0000         1
#          ADP     1.0000    0.6667    0.8000         6
#          ADV     0.0000    0.0000    0.0000         4
#          AUX     1.0000    1.0000    1.0000         1
#        CCONJ     1.0000    0.5000    0.6667         2
#          DET     0.6667    1.0000    0.8000         2
#         NOUN     0.6667    0.8571    0.7500         7
#         PRON     1.0000    0.2500    0.4000         4
#        PROPN     0.6667    1.0000    0.8000         8
#        PUNCT     1.0000    1.0000    1.0000        11
#        SCONJ     1.0000    1.0000    1.0000         2
#         VERB     0.2000    0.5000    0.2857         2
#
#     accuracy                         0.7400        50
#    macro avg     0.6833    0.6478    0.6252        50
# weighted avg     0.7547    0.7400    0.7111        50
#
# Accuracy: 0.7400   f1-score: 0.6252

# %% [markdown]
# ## Training

# %% [markdown]
# We can now training using the best hyper-parameter selected above.  This takes a few minutes.

# %%
t_ini = datetime.datetime.now()
print('Training...')
clf = LogisticRegression(C=20, solver='liblinear', random_state=13)
clf.fit(X_train, y_train)
t_fin = datetime.datetime.now()
print('Training completed in {} seconds'.format((t_fin - t_ini).total_seconds()))
# Out:
# Training...
# Training completed in 191.552127 seconds

# %% [markdown]
# # Evaluation

# %%
y_pred = clf.predict(X_test)

# %%
print("Accuracy: {0:.4f}".format(clf.score(X_test, y_test)))
print('f1-macro score: {0:.4f}'.format(f1_score(y_test, y_pred, average='macro')))
# Out:
# Accuracy: 0.9449
# f1-macro score: 0.9027

# %% [markdown]
# ## Classification Report

# %%
print(classification_report(y_test, clf.predict(X_test), digits=4))
# Out:
#               precision    recall  f1-score   support
#
#          ADJ     0.9195    0.9004    0.9099      1788
#          ADP     0.9338    0.9591    0.9463      2029
#          ADV     0.9209    0.8900    0.9052      1191
#          AUX     0.9787    0.9812    0.9799      1543
#        CCONJ     0.9946    0.9932    0.9939       736
#          DET     0.9915    0.9895    0.9905      1897
#         INTJ     0.9709    0.8264    0.8929       121
#         NOUN     0.9039    0.9195    0.9116      4123
#          NUM     0.9761    0.9779    0.9770       542
#         PART     0.9799    0.9769    0.9784       649
#         PRON     0.9853    0.9880    0.9866      2165
#        PROPN     0.8797    0.8602    0.8699      2075
#        PUNCT     0.9913    0.9968    0.9940      3096
#        SCONJ     0.8567    0.8099    0.8327       384
#          SYM     0.8725    0.8165    0.8436       109
#         VERB     0.9444    0.9582    0.9512      2606
#            X     0.5000    0.3095    0.3824        42
#
#     accuracy                         0.9449     25096
#    macro avg     0.9176    0.8914    0.9027     25096
# weighted avg     0.9444    0.9449    0.9445     25096

# %% [markdown]
# ## Frequent Types of Mistakes

# %%
import collections
k=0
i2w = id2word(test_sentences)
error_counter = collections.Counter()
for i in range(X_test.shape[0]):
    correct_tag_id = y_test
    if y_pred[i]!=y_test[i]:
        k += 1
        word = i2w[i]
        error_counter[word] += 1
print('Accuracy: {0:.4f}'.format((len(i2w)-k)/len(i2w)))
print('Total errors/Total words: {}/{}\n'.format(k,len(i2w)))
print('Most common errors:',error_counter.most_common(20))
# Out:
# Accuracy: 0.9449
# Total errors/Total words: 1383/25096
#
# Most common errors: [('that', 24), ('as', 23), ('to', 23), ('like', 22), ('out', 18), ('/', 18), ('for', 18), ('up', 18), ('in', 16), ('on', 12), ('01-Feb-02', 11), ('-', 9), ('so', 8), ('one', 8), ('much', 8), ('all', 7), ('have', 7), ('be', 7), ('of', 6), ('has', 6)]

# %% [markdown]
# ## Learning Curves

# %% [markdown]
# The following diagram illustrates the "training dynamics" of the LR model: how fast does it improve as it keeps training. Originally, the difference between the test dataset and the cross-validation (on part of the test data) is large; as training proceeds, the gap reduces. This diagram is important to verify we do not have a case of over-fitting - where the model does "very well" on training data and does not improve on test data.
#
# This computation takes a long time (as we keep training and evaluating multiple times to obtain the snapshots). It is not necessary to run the rest of the notebook so that you can safely skip it.

# %%
# plot_learning_curve(clf, 'Logistic Regression', X_train, y_train, ylim=(0.7, 1.01), cv=5)

# %% [markdown]
# ## Confusion Matrix

# %%
y_pred = clf.predict(X_test)
f1 = f1_score(y_test, y_pred, average='macro')
cnf_matrix = confusion_matrix(y_test, y_pred)
name='Logistic Regression'
plot_confusion_matrix(f1, cnf_matrix, target_names=classes, title='Confusion matrix for '+name+' classifier', normalize=False)

# %% [markdown]
# ## Tag an Unknown Sentence

# %% [markdown]
# Lets try our trained tagger on new sentences.  To tag a sentence given as a string, we must apply the following steps:
# * Tokenize the string into a list of tokens
# * Turn each token into a features dictionary (using the features used by our model)
# * Turn the list of feature dictionaries into vectors (using scikit-learn vectorization method)
# * Pass the resulting matrix (one row vector for each token) to the classifier.

# %%
# Need to download the nltk model for sentence tokenizer
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /Users/omert/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = nltk.word_tokenize('Word embeddings provide a dense representation of words and their relative meanings.')
print(tokens)
# Out:
# ['Word', 'embeddings', 'provide', 'a', 'dense', 'representation', 'of', 'words', 'and', 'their', 'relative', 'meanings', '.']

# %%
X_features = transform_test_sentence(tokens)

# %%
X_features
# Out:
# [[{'nb_terms': 13,
#    'word': 'Word',
#    'word_lower': 'word',
#    'is_first': True,
#    'is_last': False,
#    'is_capitalized': True,
#    'is_all_caps': False,
#    'is_all_lower': False,
#    'prefix-1': 'W',
#    'prefix-2': 'Wo',
#    'prefix-3': 'Wor',
#    'suffix-1': 'd',
#    'suffix-2': 'rd',
#    'suffix-3': 'ord',
#    'i-1_prefix-3': '',
#    'i-1_suffix-3': '',
#    'i+1_prefix-3': 'emb',
#    'i+1_suffix-3': 'ngs',
#    'prev_word': '',
#    'next_word': 'embeddings',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'embeddings',
#    'word_lower': 'embeddings',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'e',
#    'prefix-2': 'em',
#    'prefix-3': 'emb',
#    'suffix-1': 's',
#    'suffix-2': 'gs',
#    'suffix-3': 'ngs',
#    'i-1_prefix-3': 'Wor',
#    'i-1_suffix-3': 'ord',
#    'i+1_prefix-3': 'pro',
#    'i+1_suffix-3': 'ide',
#    'prev_word': 'word',
#    'next_word': 'provide',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'provide',
#    'word_lower': 'provide',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'p',
#    'prefix-2': 'pr',
#    'prefix-3': 'pro',
#    'suffix-1': 'e',
#    'suffix-2': 'de',
#    'suffix-3': 'ide',
#    'i-1_prefix-3': 'emb',
#    'i-1_suffix-3': 'ngs',
#    'i+1_prefix-3': 'a',
#    'i+1_suffix-3': 'a',
#    'prev_word': 'embeddings',
#    'next_word': 'a',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'a',
#    'word_lower': 'a',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'a',
#    'prefix-2': 'a',
#    'prefix-3': 'a',
#    'suffix-1': 'a',
#    'suffix-2': 'a',
#    'suffix-3': 'a',
#    'i-1_prefix-3': 'pro',
#    'i-1_suffix-3': 'ide',
#    'i+1_prefix-3': 'den',
#    'i+1_suffix-3': 'nse',
#    'prev_word': 'provide',
#    'next_word': 'dense',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'dense',
#    'word_lower': 'dense',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'd',
#    'prefix-2': 'de',
#    'prefix-3': 'den',
#    'suffix-1': 'e',
#    'suffix-2': 'se',
#    'suffix-3': 'nse',
#    'i-1_prefix-3': 'a',
#    'i-1_suffix-3': 'a',
#    'i+1_prefix-3': 'rep',
#    'i+1_suffix-3': 'ion',
#    'prev_word': 'a',
#    'next_word': 'representation',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'representation',
#    'word_lower': 'representation',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'r',
#    'prefix-2': 're',
#    'prefix-3': 'rep',
#    'suffix-1': 'n',
#    'suffix-2': 'on',
#    'suffix-3': 'ion',
#    'i-1_prefix-3': 'den',
#    'i-1_suffix-3': 'nse',
#    'i+1_prefix-3': 'of',
#    'i+1_suffix-3': 'of',
#    'prev_word': 'dense',
#    'next_word': 'of',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'of',
#    'word_lower': 'of',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'o',
#    'prefix-2': 'of',
#    'prefix-3': 'of',
#    'suffix-1': 'f',
#    'suffix-2': 'of',
#    'suffix-3': 'of',
#    'i-1_prefix-3': 'rep',
#    'i-1_suffix-3': 'ion',
#    'i+1_prefix-3': 'wor',
#    'i+1_suffix-3': 'rds',
#    'prev_word': 'representation',
#    'next_word': 'words',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'words',
#    'word_lower': 'words',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'w',
#    'prefix-2': 'wo',
#    'prefix-3': 'wor',
#    'suffix-1': 's',
#    'suffix-2': 'ds',
#    'suffix-3': 'rds',
#    'i-1_prefix-3': 'of',
#    'i-1_suffix-3': 'of',
#    'i+1_prefix-3': 'and',
#    'i+1_suffix-3': 'and',
#    'prev_word': 'of',
#    'next_word': 'and',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'and',
#    'word_lower': 'and',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'a',
#    'prefix-2': 'an',
#    'prefix-3': 'and',
#    'suffix-1': 'd',
#    'suffix-2': 'nd',
#    'suffix-3': 'and',
#    'i-1_prefix-3': 'wor',
#    'i-1_suffix-3': 'rds',
#    'i+1_prefix-3': 'the',
#    'i+1_suffix-3': 'eir',
#    'prev_word': 'words',
#    'next_word': 'their',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'their',
#    'word_lower': 'their',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 't',
#    'prefix-2': 'th',
#    'prefix-3': 'the',
#    'suffix-1': 'r',
#    'suffix-2': 'ir',
#    'suffix-3': 'eir',
#    'i-1_prefix-3': 'and',
#    'i-1_suffix-3': 'and',
#    'i+1_prefix-3': 'rel',
#    'i+1_suffix-3': 'ive',
#    'prev_word': 'and',
#    'next_word': 'relative',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'relative',
#    'word_lower': 'relative',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'r',
#    'prefix-2': 're',
#    'prefix-3': 'rel',
#    'suffix-1': 'e',
#    'suffix-2': 've',
#    'suffix-3': 'ive',
#    'i-1_prefix-3': 'the',
#    'i-1_suffix-3': 'eir',
#    'i+1_prefix-3': 'mea',
#    'i+1_suffix-3': 'ngs',
#    'prev_word': 'their',
#    'next_word': 'meanings',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': 'meanings',
#    'word_lower': 'meanings',
#    'is_first': False,
#    'is_last': False,
#    'is_capitalized': False,
#    'is_all_caps': False,
#    'is_all_lower': True,
#    'prefix-1': 'm',
#    'prefix-2': 'me',
#    'prefix-3': 'mea',
#    'suffix-1': 's',
#    'suffix-2': 'gs',
#    'suffix-3': 'ngs',
#    'i-1_prefix-3': 'rel',
#    'i-1_suffix-3': 'ive',
#    'i+1_prefix-3': '.',
#    'i+1_suffix-3': '.',
#    'prev_word': 'relative',
#    'next_word': '.',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}],
#  [{'nb_terms': 13,
#    'word': '.',
#    'word_lower': '.',
#    'is_first': False,
#    'is_last': True,
#    'is_capitalized': True,
#    'is_all_caps': True,
#    'is_all_lower': True,
#    'prefix-1': '.',
#    'prefix-2': '.',
#    'prefix-3': '.',
#    'suffix-1': '.',
#    'suffix-2': '.',
#    'suffix-3': '.',
#    'i-1_prefix-3': 'mea',
#    'i-1_suffix-3': 'ngs',
#    'i+1_prefix-3': '',
#    'i+1_suffix-3': '',
#    'prev_word': 'meanings',
#    'next_word': '',
#    'has_hyphen': False,
#    'is_numeric': False,
#    'capitals_inside': False}]]

# %%
X_vectorized = vec.transform([x[0] for x in X_features])

# %%
# The vectorized sentence is a sparse matrix with one row for each token and columns for the vectorized features
# For example, if the vocabulary has 1000 unique words, the vectorized sentence will have 1000 columns for each word feature.
# This is a very sparse matrix, where most of the values are zero.
X_vectorized.shape
# Out:
# (13, 98719)

# %%
pred = clf.predict(X_vectorized)

# %%
# np.str_ is a subclass of str that is used to represent string arrays in NumPy.
print('Here is what our LR tagger predicts for the test sentence:\n',list(zip(tokens, pred)))
# Out:
# Here is what our LR tagger predicts for the test sentence:
#  [('Word', 'PROPN'), ('embeddings', 'NOUN'), ('provide', 'VERB'), ('a', 'DET'), ('dense', 'ADJ'), ('representation', 'NOUN'), ('of', 'ADP'), ('words', 'NOUN'), ('and', 'CCONJ'), ('their', 'PRON'), ('relative', 'ADJ'), ('meanings', 'NOUN'), ('.', 'PUNCT')]

# %% [markdown]
# Let's turn this process into a prediction function from a sentence encoded as a single string to a list of pairs (token, predicted_tag):

# %%
def predict_sentence(sentence):
   tokens = nltk.word_tokenize(sentence)
   X_features = transform_test_sentence(tokens)
   X_vectorized = vec.transform([x[0] for x in X_features])
   pred = clf.predict(X_vectorized)
   return list(zip(tokens, pred))

# %%
predict_sentence("Let me join the chorus of annoyance over Google's new toolbar , which, as noted in the linked article, commits just about every sin an online marketer could commit, and makes up a few new ones besides.")
# Out:
# [('Let', 'VERB'),
#  ('me', 'PRON'),
#  ('join', 'VERB'),
#  ('the', 'DET'),
#  ('chorus', 'NOUN'),
#  ('of', 'ADP'),
#  ('annoyance', 'NOUN'),
#  ('over', 'ADP'),
#  ('Google', 'PROPN'),
#  ("'s", 'PART'),
#  ('new', 'ADJ'),
#  ('toolbar', 'NOUN'),
#  (',', 'PUNCT'),
#  ('which', 'PRON'),
#  (',', 'PUNCT'),
#  ('as', 'SCONJ'),
#  ('noted', 'VERB'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('linked', 'VERB'),
#  ('article', 'NOUN'),
#  (',', 'PUNCT'),
#  ('commits', 'NOUN'),
#  ('just', 'ADV'),
#  ('about', 'ADV'),
#  ('every', 'DET'),
#  ('sin', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'ADJ'),
#  ('marketer', 'NOUN'),
#  ('could', 'AUX'),
#  ('commit', 'VERB'),
#  (',', 'PUNCT'),
#  ('and', 'CCONJ'),
#  ('makes', 'VERB'),
#  ('up', 'ADP'),
#  ('a', 'DET'),
#  ('few', 'ADJ'),
#  ('new', 'ADJ'),
#  ('ones', 'NOUN'),
#  ('besides', 'ADP'),
#  ('.', 'PUNCT')]

# %% [markdown]
# # Collect Hard Sentences
#
# Hard sentences are sentences that contain multiple wrongly predicted tags given our classifier.
#
# Write code to collect hard sentences given a classifier clf.

# %%
def errors_in_sentence_prediction(clf, tagged_sentence):
    """Given a tagged sentence from the dataset, return the number of errors and the predicted tags."""
    errors = 0
    tokens = untag(tagged_sentence)
    actual_tags = untag_pos(tagged_sentence)
    
    # Get features for each token in the sentence
    X_features = transform_test_sentence(tokens)
    # Vectorize the features
    X_vectorized = vec.transform([x[0] for x in X_features])
    # Predict tags
    pred = clf.predict(X_vectorized)
    
    # Count errors
    for i in range(len(pred)):
        if pred[i] != actual_tags[i]:
            errors += 1
            
    return errors, pred

# %%
hard_sentences = []
for s in test_sentences:
    errors, pred = errors_in_sentence_prediction(clf, s)
    if errors > 0:
        hard_sentences.append((s, errors, pred))
print(f'Number of sentences with errors: {len(hard_sentences)} out of {len(test_sentences)}')
# Out:
# Number of sentences with errors: 802 out of 2077

# %% [markdown]
# Draw a histogram showing how the sentences in the test dataset are distributed in terms of prediction errors per sentence.

# %%
# Draw a histogram of the number of errors per sentence
plt.figure(figsize=(10, 6))
plt.hist([x[1] for x in hard_sentences], bins=16, edgecolor='black')
plt.title('Number of errors per sentence')
plt.xlabel('Number of errors')
plt.ylabel('Number of sentences')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Show prediction errors for sentences with more than 5 errors.
for s in hard_sentences:
    if s[1] > 5:
        print(" ".join(untag(s[0])))
        print('Number of errors:', s[1])
        for i in range(len(s[0])):
            if s[0][i][1] != s[2][i]:
                print(f'{s[0][i][0]:<20}  C: {s[0][i][1]:<12}  P: {s[2][i]:<12} **** Error')
            else:
                print(f'{s[0][i][0]:<23}  {s[0][i][1]:<12}')
        print(40*'=')
# Out:
# Stay with me now : John Paul STEVENS delivered the opinion of the Court with respect to Parts I through IV , VI through VI - D - iii , VI - D - v , and VII , in which KENNEDY , SOUTER , GINSBURG , and BREYER joined , and an opinion with respect to Parts V and VI - D - iv , in which SOUTER , GINSBURG , and BREYER joined .
# Number of errors: 8
# Stay                     VERB
# with                     ADP
# me                       PRON
# now                      ADV
# :                        PUNCT
# John                     PROPN
# Paul                     PROPN
# STEVENS               C: PROPN         P: NOUN         **** Error
# delivered                VERB
# the                      DET
# opinion                  NOUN
# of                       ADP
# the                      DET
# Court                    NOUN
# with                     ADP
# respect                  NOUN
# to                       ADP
# Parts                 C: NOUN          P: PROPN        **** Error
# I                     C: NUM           P: PRON         **** Error
# through                  ADP
# IV                    C: NUM           P: NOUN         **** Error
# ,                        PUNCT
# VI                       NUM
# through                  ADP
# VI                       NUM
# -                        PUNCT
# D                        NOUN
# -                        PUNCT
# iii                   C: NUM           P: NOUN         **** Error
# ,                        PUNCT
# VI                       NUM
# -                        PUNCT
# D                        NOUN
# -                        PUNCT
# v                     C: NUM           P: NOUN         **** Error
# ,                        PUNCT
# and                      CCONJ
# VII                      NUM
# ,                        PUNCT
# in                       ADP
# which                    PRON
# KENNEDY                  PROPN
# ,                        PUNCT
# SOUTER                   PROPN
# ,                        PUNCT
# GINSBURG                 PROPN
# ,                        PUNCT
# and                      CCONJ
# BREYER                   PROPN
# joined                   VERB
# ,                        PUNCT
# and                      CCONJ
# an                       DET
# opinion                  NOUN
# with                     ADP
# respect                  NOUN
# to                       ADP
# Parts                 C: NOUN          P: PROPN        **** Error
# V                        NUM
# and                      CCONJ
# VI                       NUM
# -                        PUNCT
# D                        NOUN
# -                        PUNCT
# iv                    C: NUM           P: NOUN         **** Error
# ,                        PUNCT
# in                       ADP
# which                    PRON
# SOUTER                   PROPN
# ,                        PUNCT
# GINSBURG                 PROPN
# ,                        PUNCT
# and                      CCONJ
# BREYER                   PROPN
# joined                   VERB
# .                        PUNCT
# ========================================
# It does n't change the company 's intrinsic worth , and as the article notes , the company might be added to a major index once the shares get more liquid .
# Number of errors: 6
# It                       PRON
# does                     AUX
# n't                      PART
# change                   VERB
# the                      DET
# company                  NOUN
# 's                       PART
# intrinsic             C: ADJ           P: NOUN         **** Error
# worth                 C: NOUN          P: ADJ          **** Error
# ,                        PUNCT
# and                      CCONJ
# as                    C: SCONJ         P: ADP          **** Error
# the                      DET
# article                  NOUN
# notes                 C: VERB          P: NOUN         **** Error
# ,                        PUNCT
# the                      DET
# company                  NOUN
# might                    AUX
# be                       AUX
# added                    VERB
# to                       ADP
# a                        DET
# major                    ADJ
# index                    NOUN
# once                     SCONJ
# the                      DET
# shares                   NOUN
# get                      VERB
# more                  C: ADV           P: ADJ          **** Error
# liquid                C: ADJ           P: NOUN         **** Error
# .                        PUNCT
# ========================================
# Magali Van Belle Consultant PHB Hagler Bailly MANAGEMENT AND ECONOMIC CONSULTANTS PHB Hagler Bailly , Inc. ( 202 ) 828-3933 direct dial 1776 Eye Street , N.W. ( 202 ) 296-3858 facsimile Washington , D.C. 20006-3700 mvanbell@haglerbailly.com e-mail
# Number of errors: 7
# Magali                   PROPN
# Van                      PROPN
# Belle                    PROPN
# Consultant            C: NOUN          P: PROPN        **** Error
# PHB                      PROPN
# Hagler                   PROPN
# Bailly                C: PROPN         P: ADV          **** Error
# MANAGEMENT            C: PROPN         P: ADJ          **** Error
# AND                      CCONJ
# ECONOMIC              C: ADJ           P: PROPN        **** Error
# CONSULTANTS           C: PROPN         P: NOUN         **** Error
# PHB                      PROPN
# Hagler                   PROPN
# Bailly                C: PROPN         P: ADV          **** Error
# ,                        PUNCT
# Inc.                     PROPN
# (                        PUNCT
# 202                      NUM
# )                        PUNCT
# 828-3933                 NUM
# direct                   ADJ
# dial                  C: NOUN          P: VERB         **** Error
# 1776                     NUM
# Eye                      PROPN
# Street                   PROPN
# ,                        PUNCT
# N.W.                     PROPN
# (                        PUNCT
# 202                      NUM
# )                        PUNCT
# 296-3858                 NUM
# facsimile                NOUN
# Washington               PROPN
# ,                        PUNCT
# D.C.                     PROPN
# 20006-3700               NUM
# mvanbell@haglerbailly.com  PROPN
# e-mail                   NOUN
# ========================================
# - Ram Tackett ( E-mail ) .vcf 4222
# Number of errors: 6
# -                        PUNCT
# Ram                   C: NOUN          P: PROPN        **** Error
# Tackett               C: X             P: PROPN        **** Error
# (                     C: X             P: PUNCT        **** Error
# E-mail                C: X             P: NOUN         **** Error
# )                     C: X             P: PUNCT        **** Error
# .vcf                  C: X             P: PUNCT        **** Error
# 4222                     NUM
# ========================================
# Attached are clean and blacklined drafts of the Enron guaranties to be made in support of EPMI 's obligations under the Indian Mesa II Renewable Energy Purchase Agreement ( " PPA " ) and Green Premium Sharing Agreement ( " GSPA " ) .?
# Number of errors: 6
# Attached                 VERB
# are                      AUX
# clean                    ADJ
# and                      CCONJ
# blacklined               VERB
# drafts                   NOUN
# of                       ADP
# the                      DET
# Enron                    PROPN
# guaranties               NOUN
# to                       PART
# be                       AUX
# made                     VERB
# in                       ADP
# support                  NOUN
# of                       ADP
# EPMI                     PROPN
# 's                       PART
# obligations              NOUN
# under                    ADP
# the                      DET
# Indian                   ADJ
# Mesa                     PROPN
# II                       NUM
# Renewable                ADJ
# Energy                C: PROPN         P: NOUN         **** Error
# Purchase              C: PROPN         P: NOUN         **** Error
# Agreement             C: PROPN         P: NOUN         **** Error
# (                        PUNCT
# "                        PUNCT
# PPA                   C: PROPN         P: NOUN         **** Error
# "                        PUNCT
# )                        PUNCT
# and                      CCONJ
# Green                    ADJ
# Premium                  PROPN
# Sharing               C: PROPN         P: VERB         **** Error
# Agreement             C: PROPN         P: NOUN         **** Error
# (                        PUNCT
# "                        PUNCT
# GSPA                     PROPN
# "                        PUNCT
# )                        PUNCT
# .?                       PUNCT
# ========================================
# We have started a new forum for an interactive and absorbing discussion on Astrology & Palmistry and everything in between including Gemology , Feng Shui / Vaastu Shastra .
# Number of errors: 9
# We                       PRON
# have                     AUX
# started                  VERB
# a                        DET
# new                      ADJ
# forum                    NOUN
# for                      ADP
# an                       DET
# interactive              ADJ
# and                      CCONJ
# absorbing             C: ADJ           P: VERB         **** Error
# discussion               NOUN
# on                       ADP
# Astrology             C: NOUN          P: PROPN        **** Error
# &                        CCONJ
# Palmistry             C: NOUN          P: PROPN        **** Error
# and                      CCONJ
# everything               PRON
# in                       ADP
# between                  ADP
# including                VERB
# Gemology              C: NOUN          P: PROPN        **** Error
# ,                        PUNCT
# Feng                  C: NOUN          P: PROPN        **** Error
# Shui                  C: NOUN          P: PROPN        **** Error
# /                     C: SYM           P: PUNCT        **** Error
# Vaastu                C: NOUN          P: PROPN        **** Error
# Shastra               C: NOUN          P: PROPN        **** Error
# .                        PUNCT
# ========================================
# Twinkle Twinkle lazy star Kitna soyega uthja yaar , up above the world so high , sun has risen in the sky , uthke jaldi pee le chai , then call me up and say " HI "
# Number of errors: 15
# Twinkle               C: VERB          P: PROPN        **** Error
# Twinkle               C: VERB          P: PROPN        **** Error
# lazy                     ADJ
# star                     NOUN
# Kitna                 C: X             P: PROPN        **** Error
# soyega                C: X             P: PROPN        **** Error
# uthja                 C: X             P: NOUN         **** Error
# yaar                  C: X             P: NOUN         **** Error
# ,                        PUNCT
# up                    C: ADV           P: ADP          **** Error
# above                    ADP
# the                      DET
# world                    NOUN
# so                       ADV
# high                  C: ADV           P: ADJ          **** Error
# ,                        PUNCT
# sun                      NOUN
# has                   C: AUX           P: VERB         **** Error
# risen                    VERB
# in                       ADP
# the                      DET
# sky                      NOUN
# ,                        PUNCT
# uthke                 C: X             P: ADJ          **** Error
# jaldi                 C: X             P: PROPN        **** Error
# pee                   C: X             P: NOUN         **** Error
# le                    C: X             P: NOUN         **** Error
# chai                  C: X             P: NOUN         **** Error
# ,                        PUNCT
# then                     ADV
# call                     VERB
# me                       PRON
# up                       ADP
# and                      CCONJ
# say                      VERB
# "                        PUNCT
# HI                    C: INTJ          P: NOUN         **** Error
# "                        PUNCT
# ========================================
# You will always find fascinating links at : Extreme Web Surfs http://extremewebsurfs.blogspot.com/ ( nice urban wildlife post today ) & Me and the Web http://maartenvt.blogspot.com/ Arts , History , Animals , Music , Games , Politics , Technology , Fun and more !
# Number of errors: 9
# You                      PRON
# will                     AUX
# always                   ADV
# find                     VERB
# fascinating              ADJ
# links                    NOUN
# at                       ADP
# :                        PUNCT
# Extreme                  ADJ
# Web                   C: PROPN         P: NOUN         **** Error
# Surfs                 C: PROPN         P: NOUN         **** Error
# http://extremewebsurfs.blogspot.com/  PROPN
# (                        PUNCT
# nice                     ADJ
# urban                    ADJ
# wildlife                 NOUN
# post                  C: NOUN          P: VERB         **** Error
# today                    NOUN
# )                        PUNCT
# &                        CCONJ
# Me                       PRON
# and                      CCONJ
# the                      DET
# Web                   C: PROPN         P: NOUN         **** Error
# http://maartenvt.blogspot.com/  PROPN
# Arts                  C: NOUN          P: PROPN        **** Error
# ,                        PUNCT
# History                  NOUN
# ,                        PUNCT
# Animals                  NOUN
# ,                        PUNCT
# Music                 C: NOUN          P: PROPN        **** Error
# ,                        PUNCT
# Games                    NOUN
# ,                        PUNCT
# Politics              C: NOUN          P: PROPN        **** Error
# ,                        PUNCT
# Technology            C: NOUN          P: PROPN        **** Error
# ,                        PUNCT
# Fun                   C: NOUN          P: PROPN        **** Error
# and                      CCONJ
# more                     ADJ
# !                        PUNCT
# ========================================
# WE HAVE A DATE FOR THE RELEASE OF RAGNAROK ONLINE 2 ( beta anyway ) September 16 - 18 , this was announced by Gravity CEO Kim Jung - Ryool on either 16th or 17th of july and as i do n't want to take someone 's credit's i got it here ^^ GameSpot
# Number of errors: 7
# WE                       PRON
# HAVE                     VERB
# A                        DET
# DATE                     NOUN
# FOR                      ADP
# THE                      DET
# RELEASE                  NOUN
# OF                       ADP
# RAGNAROK                 PROPN
# ONLINE                C: ADJ           P: NOUN         **** Error
# 2                        NUM
# (                        PUNCT
# beta                     NOUN
# anyway                   ADV
# )                        PUNCT
# September                PROPN
# 16                       NUM
# -                     C: SYM           P: PUNCT        **** Error
# 18                       NUM
# ,                        PUNCT
# this                     PRON
# was                      AUX
# announced                VERB
# by                       ADP
# Gravity               C: PROPN         P: NOUN         **** Error
# CEO                      NOUN
# Kim                      PROPN
# Jung                     PROPN
# -                        PUNCT
# Ryool                    PROPN
# on                       ADP
# either                   CCONJ
# 16th                  C: NOUN          P: ADJ          **** Error
# or                       CCONJ
# 17th                  C: NOUN          P: ADJ          **** Error
# of                       ADP
# july                  C: PROPN         P: ADV          **** Error
# and                      CCONJ
# as                       SCONJ
# i                        PRON
# do                       AUX
# n't                      PART
# want                     VERB
# to                       PART
# take                     VERB
# someone                  PRON
# 's                       PART
# credit's                 NOUN
# i                        PRON
# got                      VERB
# it                       PRON
# here                     ADV
# ^^                    C: SYM           P: PUNCT        **** Error
# GameSpot                 PROPN
# ========================================
# which burger chain do you think is as good as in n out or better in the chicago area besides five guys and smashburger ?
# Number of errors: 7
# which                 C: DET           P: PRON         **** Error
# burger                   NOUN
# chain                    NOUN
# do                       AUX
# you                      PRON
# think                    VERB
# is                       AUX
# as                       ADV
# good                     ADJ
# as                       ADP
# in                    C: PROPN         P: ADV          **** Error
# n                     C: CCONJ         P: PART         **** Error
# out                   C: PROPN         P: VERB         **** Error
# or                       CCONJ
# better                   ADJ
# in                       ADP
# the                      DET
# chicago                  PROPN
# area                     NOUN
# besides                  ADP
# five                  C: PROPN         P: NUM          **** Error
# guys                  C: PROPN         P: NOUN         **** Error
# and                      CCONJ
# smashburger           C: PROPN         P: ADJ          **** Error
# ?                        PUNCT
# ========================================
# I 've been looking at the bose sound dock 10 i ve currently got a jvc mini hifi system , i was wondering what would be a good set of speakers .
# Number of errors: 6
# I                        PRON
# 've                      AUX
# been                     AUX
# looking                  VERB
# at                       ADP
# the                      DET
# bose                  C: PROPN         P: NOUN         **** Error
# sound                 C: PROPN         P: NOUN         **** Error
# dock                  C: PROPN         P: NOUN         **** Error
# 10                       NUM
# i                        PRON
# ve                    C: AUX           P: VERB         **** Error
# currently                ADV
# got                      VERB
# a                        DET
# jvc                   C: PROPN         P: NOUN         **** Error
# mini                  C: X             P: ADJ          **** Error
# hifi                     NOUN
# system                   NOUN
# ,                        PUNCT
# i                        PRON
# was                      AUX
# wondering                VERB
# what                     PRON
# would                    AUX
# be                       AUX
# a                        DET
# good                     ADJ
# set                      NOUN
# of                       ADP
# speakers                 NOUN
# .                        PUNCT
# ========================================
# any Ice Cream In NZ no matter where as New Zealand has the best bl**dy ice cream in the world I was in NZ for a few weeks had some Ice Cream and really enjoyed it I will go back just to eat some Ice Cream
# Number of errors: 7
# any                      DET
# Ice                   C: NOUN          P: PROPN        **** Error
# Cream                 C: NOUN          P: PROPN        **** Error
# In                       ADP
# NZ                       PROPN
# no                       DET
# matter                   NOUN
# where                    ADV
# as                    C: SCONJ         P: ADP          **** Error
# New                      ADJ
# Zealand                  PROPN
# has                      VERB
# the                      DET
# best                     ADJ
# bl**dy                   ADJ
# ice                      NOUN
# cream                    NOUN
# in                       ADP
# the                      DET
# world                    NOUN
# I                        PRON
# was                      AUX
# in                       ADP
# NZ                       PROPN
# for                      ADP
# a                        DET
# few                      ADJ
# weeks                    NOUN
# had                      VERB
# some                     DET
# Ice                   C: NOUN          P: PROPN        **** Error
# Cream                 C: NOUN          P: PROPN        **** Error
# and                      CCONJ
# really                   ADV
# enjoyed                  VERB
# it                       PRON
# I                        PRON
# will                     AUX
# go                       VERB
# back                     ADV
# just                     ADV
# to                       PART
# eat                      VERB
# some                     DET
# Ice                   C: NOUN          P: PROPN        **** Error
# Cream                 C: NOUN          P: PROPN        **** Error
# ========================================
# which is the best burger chain in the chicago metro area like for example burger king portillo s white castle which one do you like the best ?
# Number of errors: 9
# which                    PRON
# is                       AUX
# the                      DET
# best                     ADJ
# burger                   NOUN
# chain                    NOUN
# in                       ADP
# the                      DET
# chicago                  PROPN
# metro                 C: ADJ           P: PROPN        **** Error
# area                     NOUN
# like                  C: INTJ          P: ADP          **** Error
# for                      ADP
# example                  NOUN
# burger                C: PROPN         P: NOUN         **** Error
# king                  C: PROPN         P: NOUN         **** Error
# portillo              C: PROPN         P: NOUN         **** Error
# s                        PART
# white                    ADJ
# castle                C: PROPN         P: NOUN         **** Error
# which                 C: DET           P: PRON         **** Error
# one                   C: NOUN          P: PRON         **** Error
# do                       AUX
# you                      PRON
# like                     VERB
# the                      DET
# best                  C: ADV           P: ADJ          **** Error
# ?                        PUNCT
# ========================================
# My canon t2i stops working at times as in the power bottom is switched to " on " but the camera does not respond to any function .
# Number of errors: 6
# My                       PRON
# canon                 C: PROPN         P: NOUN         **** Error
# t2i                      PROPN
# stops                 C: VERB          P: NOUN         **** Error
# working                  VERB
# at                       ADP
# times                    NOUN
# as                    C: SCONJ         P: ADP          **** Error
# in                    C: SCONJ         P: ADP          **** Error
# the                      DET
# power                    NOUN
# bottom                   NOUN
# is                       AUX
# switched                 VERB
# to                    C: ADP           P: PART         **** Error
# "                        PUNCT
# on                    C: NOUN          P: ADP          **** Error
# "                        PUNCT
# but                      CCONJ
# the                      DET
# camera                   NOUN
# does                     AUX
# not                      PART
# respond                  VERB
# to                       ADP
# any                      DET
# function                 NOUN
# .                        PUNCT
# ========================================
# Here is the stocking for my 150 gallon tank i upgraded it to 200 at the weekend because of the clownloach A 200 gallon with 6 pairs of Breeding Angel fish fire mouth honey Gouramis 5 8 inch clownloach a Krib and 5 1 inch clown loach with 16 cory cats 5 Australian Rainbows
# Number of errors: 6
# Here                     ADV
# is                       AUX
# the                      DET
# stocking                 NOUN
# for                      ADP
# my                       PRON
# 150                      NUM
# gallon                   NOUN
# tank                     NOUN
# i                        PRON
# upgraded                 VERB
# it                       PRON
# to                       ADP
# 200                      NUM
# at                       ADP
# the                      DET
# weekend                  NOUN
# because                  ADP
# of                       ADP
# the                      DET
# clownloach               NOUN
# A                        DET
# 200                      NUM
# gallon                   NOUN
# with                     ADP
# 6                        NUM
# pairs                    NOUN
# of                       ADP
# Breeding              C: NOUN          P: PROPN        **** Error
# Angel                 C: NOUN          P: PROPN        **** Error
# fish                     NOUN
# fire                     NOUN
# mouth                    NOUN
# honey                    NOUN
# Gouramis              C: NOUN          P: PROPN        **** Error
# 5                        NUM
# 8                        NUM
# inch                     NOUN
# clownloach               NOUN
# a                        DET
# Krib                  C: NOUN          P: PROPN        **** Error
# and                      CCONJ
# 5                        NUM
# 1                        NUM
# inch                     NOUN
# clown                 C: NOUN          P: ADJ          **** Error
# loach                    NOUN
# with                     ADP
# 16                       NUM
# cory                     NOUN
# cats                     NOUN
# 5                        NUM
# Australian               ADJ
# Rainbows              C: NOUN          P: PROPN        **** Error
# ========================================

# %% [markdown]
# ##

# %% [markdown]
# ## Error Analysis
#
# 1. Identify tokens that are misclassified more than 10 times in the test set. Print the sentences where the errors are predicted (about 100 sentences).
# 2. Provide a possible reason why these errors are made by the tagger based on your understanding of the knowledge needed to correctly tag these tokens.
# 3. Based on this error analysis, invent five sentences that are badly tagged. Explain what is your method to create these hard examples.

# %% [markdown]
# 1. Identify tokens that are misclassified more than 10 times in the test set. Print the sentences where the errors are predicted (about 100 sentences).

# %%
# Create a counter to track misclassified tokens
misclassified_tokens = collections.Counter()

# Count how many times each token is misclassified
for s in hard_sentences:
    sentence, errors, pred_tags = s
    for i in range(len(sentence)):
        token, gold_tag = sentence[i]
        pred_tag = pred_tags[i]
        if gold_tag != pred_tag:
            misclassified_tokens[token] += 1

# Find tokens misclassified more than 10 times
frequent_errors = {token: count for token, count in misclassified_tokens.items() if count > 10}

# Sort them by frequency (most frequent first)
sorted_frequent_errors = sorted(frequent_errors.items(), key=lambda x: x[1], reverse=True)

# Print the most frequently misclassified tokens
print("Tokens misclassified more than 10 times:")
for token, count in sorted_frequent_errors:
    print(f"{token}: {count} times")

print("\nTotal frequently misclassified tokens:", len(sorted_frequent_errors))

# Find and print sentences where frequently misclassified tokens have prediction errors
print("\nSentences where frequently misclassified tokens are predicted incorrectly:")
print(40*'=')

sentences_shown = 0
max_sentences = 100
frequent_tokens = set(token for token, _ in sorted_frequent_errors)

for s in hard_sentences:
    sentence, errors, pred_tags = s
    has_frequent_error = False
    
    # Check if this sentence contains any frequently misclassified tokens as errors
    for i in range(len(sentence)):
        token, gold_tag = sentence[i]
        pred_tag = pred_tags[i]
        if token in frequent_tokens and gold_tag != pred_tag:
            has_frequent_error = True
            break
    
    if has_frequent_error:
        # Print the sentence
        print(" ".join(untag(sentence)))
        print('Number of errors:', errors)
        
        # Print token-by-token details
        for i in range(len(sentence)):
            token, gold_tag = sentence[i]
            pred_tag = pred_tags[i]
            if token in frequent_tokens and gold_tag != pred_tag:
                print(f'{token:<20}  C: {gold_tag:<12}  P: {pred_tag:<12} **** Frequent Error')
            elif gold_tag != pred_tag:
                print(f'{token:<20}  C: {gold_tag:<12}  P: {pred_tag:<12} **** Error')
            else:
                print(f'{token:<20}  {gold_tag:<12}')
        
        print(40*'=')
        sentences_shown += 1
        
        if sentences_shown >= max_sentences:
            print(f"Showing {sentences_shown} of the sentences containing frequently misclassified tokens.")
            break

print(f"Total sentences shown: {sentences_shown}")
# Out:
# Tokens misclassified more than 10 times:
# that: 24 times
# as: 23 times
# to: 23 times
# like: 22 times
# out: 18 times
# /: 18 times
# for: 18 times
# up: 18 times
# in: 16 times
# on: 12 times
# 01-Feb-02: 11 times
#
# Total frequently misclassified tokens: 11
#
# Sentences where frequently misclassified tokens are predicted incorrectly:
# ========================================
# I doubt the very few who actually read my blog have not come across this yet , but I figured I would put it out there anyways .
# Number of errors: 2
# I                     PRON
# doubt                 VERB
# the                   DET
# very                  ADV
# few                   ADJ
# who                   PRON
# actually              ADV
# read                  VERB
# my                    PRON
# blog                  NOUN
# have                  AUX
# not                   PART
# come                  VERB
# across                ADP
# this                  PRON
# yet                   ADV
# ,                     PUNCT
# but                   CCONJ
# I                     PRON
# figured               VERB
# I                     PRON
# would                 AUX
# put                   VERB
# it                    PRON
# out                   C: ADV           P: ADP          **** Frequent Error
# there                 ADV
# anyways               C: ADV           P: VERB         **** Error
# .                     PUNCT
# ========================================
# John Donovan from Argghhh! has put out a excellent slide show on what was actually found and fought for in Fallujah .
# Number of errors: 1
# John                  PROPN
# Donovan               PROPN
# from                  ADP
# Argghhh!              PROPN
# has                   AUX
# put                   VERB
# out                   ADP
# a                     DET
# excellent             ADJ
# slide                 NOUN
# show                  NOUN
# on                    C: SCONJ         P: ADP          **** Frequent Error
# what                  PRON
# was                   AUX
# actually              ADV
# found                 VERB
# and                   CCONJ
# fought                VERB
# for                   ADP
# in                    ADP
# Fallujah              PROPN
# .                     PUNCT
# ========================================
# Angry crowds chanted anti-American slogans in the western city of Falluja ( pop. 256,000 ) as the security police killed in a friendly fire incident by US troops were buried on Saturday .
# Number of errors: 2
# Angry                 C: ADJ           P: PROPN        **** Error
# crowds                NOUN
# chanted               VERB
# anti-American         ADJ
# slogans               NOUN
# in                    ADP
# the                   DET
# western               ADJ
# city                  NOUN
# of                    ADP
# Falluja               PROPN
# (                     PUNCT
# pop.                  NOUN
# 256,000               NUM
# )                     PUNCT
# as                    C: SCONJ         P: ADP          **** Frequent Error
# the                   DET
# security              NOUN
# police                NOUN
# killed                VERB
# in                    ADP
# a                     DET
# friendly              ADJ
# fire                  NOUN
# incident              NOUN
# by                    ADP
# US                    PROPN
# troops                NOUN
# were                  AUX
# buried                VERB
# on                    ADP
# Saturday              PROPN
# .                     PUNCT
# ========================================
# Let aggressive ( American ) leaders and soldiers know that we are capable of protecting the city 's security and safety , and ask them to lift their hands from the city . "
# Number of errors: 1
# Let                   VERB
# aggressive            ADJ
# (                     PUNCT
# American              ADJ
# )                     PUNCT
# leaders               NOUN
# and                   CCONJ
# soldiers              NOUN
# know                  VERB
# that                  SCONJ
# we                    PRON
# are                   AUX
# capable               ADJ
# of                    SCONJ
# protecting            VERB
# the                   DET
# city                  NOUN
# 's                    PART
# security              NOUN
# and                   CCONJ
# safety                NOUN
# ,                     PUNCT
# and                   CCONJ
# ask                   VERB
# them                  PRON
# to                    C: PART          P: ADP          **** Frequent Error
# lift                  VERB
# their                 PRON
# hands                 NOUN
# from                  ADP
# the                   DET
# city                  NOUN
# .                     PUNCT
# "                     PUNCT
# ========================================
# KENNEDY filed an opinion concurring in part , in which SOUTER , GINSBURG , and BREYER joined as to Parts I and II .
# Number of errors: 4
# KENNEDY               C: PROPN         P: NOUN         **** Error
# filed                 VERB
# an                    DET
# opinion               NOUN
# concurring            VERB
# in                    ADP
# part                  NOUN
# ,                     PUNCT
# in                    ADP
# which                 PRON
# SOUTER                PROPN
# ,                     PUNCT
# GINSBURG              PROPN
# ,                     PUNCT
# and                   CCONJ
# BREYER                PROPN
# joined                VERB
# as                    C: ADP           P: SCONJ        **** Frequent Error
# to                    ADP
# Parts                 C: NOUN          P: PROPN        **** Error
# I                     C: NUM           P: PRON         **** Error
# and                   CCONJ
# II                    NUM
# .                     PUNCT
# ========================================
# THOMAS filed a dissenting opinion , in which SCALIA joined , and in which ALITO joined as to all but Parts I , II - C - 1 , and III - B - 2 .
# Number of errors: 5
# THOMAS                C: PROPN         P: AUX          **** Error
# filed                 VERB
# a                     DET
# dissenting            VERB
# opinion               NOUN
# ,                     PUNCT
# in                    ADP
# which                 PRON
# SCALIA                PROPN
# joined                VERB
# ,                     PUNCT
# and                   CCONJ
# in                    ADP
# which                 PRON
# ALITO                 PROPN
# joined                VERB
# as                    C: ADP           P: SCONJ        **** Frequent Error
# to                    ADP
# all                   DET
# but                   C: ADP           P: CCONJ        **** Error
# Parts                 NOUN
# I                     C: NUM           P: PRON         **** Error
# ,                     PUNCT
# II                    NUM
# -                     PUNCT
# C                     NOUN
# -                     PUNCT
# 1                     NUM
# ,                     PUNCT
# and                   CCONJ
# III                   NUM
# -                     PUNCT
# B                     C: NOUN          P: ADJ          **** Error
# -                     PUNCT
# 2                     NUM
# .                     PUNCT
# ========================================
# ALITO filed a dissenting opinion , in which SCALIA and THOMAS joined as to Parts I through III .
# Number of errors: 3
# ALITO                 PROPN
# filed                 VERB
# a                     DET
# dissenting            VERB
# opinion               NOUN
# ,                     PUNCT
# in                    ADP
# which                 PRON
# SCALIA                PROPN
# and                   CCONJ
# THOMAS                PROPN
# joined                VERB
# as                    C: ADP           P: SCONJ        **** Frequent Error
# to                    ADP
# Parts                 C: NOUN          P: PROPN        **** Error
# I                     C: NUM           P: PRON         **** Error
# through               ADP
# III                   NUM
# .                     PUNCT
# ========================================
# Important news such as President Bush 's miniscule calibrations on his marriage amendment / anti-gay ( update : he 's not against gays in the bedroom , just at the altar , where of course their relationships should not only be frowned upon but should be constitutionally excluded ) has pushed Sudan not just off the front pages , or the A section , but out of the NY Times and Washington Post completely .
# Number of errors: 3
# Important             ADJ
# news                  NOUN
# such                  ADJ
# as                    ADP
# President             PROPN
# Bush                  PROPN
# 's                    PART
# miniscule             ADJ
# calibrations          NOUN
# on                    ADP
# his                   PRON
# marriage              NOUN
# amendment             NOUN
# /                     C: SYM           P: PUNCT        **** Frequent Error
# anti-gay              ADJ
# (                     PUNCT
# update                NOUN
# :                     PUNCT
# he                    PRON
# 's                    AUX
# not                   PART
# against               ADP
# gays                  NOUN
# in                    ADP
# the                   DET
# bedroom               NOUN
# ,                     PUNCT
# just                  ADV
# at                    ADP
# the                   DET
# altar                 NOUN
# ,                     PUNCT
# where                 ADV
# of                    ADP
# course                NOUN
# their                 PRON
# relationships         NOUN
# should                AUX
# not                   PART
# only                  ADV
# be                    AUX
# frowned               VERB
# upon                  ADP
# but                   CCONJ
# should                AUX
# be                    AUX
# constitutionally      ADV
# excluded              VERB
# )                     PUNCT
# has                   AUX
# pushed                VERB
# Sudan                 PROPN
# not                   PART
# just                  ADV
# off                   ADP
# the                   DET
# front                 C: ADJ           P: NOUN         **** Error
# pages                 NOUN
# ,                     PUNCT
# or                    CCONJ
# the                   DET
# A                     C: NOUN          P: DET          **** Error
# section               NOUN
# ,                     PUNCT
# but                   CCONJ
# out                   ADP
# of                    ADP
# the                   DET
# NY                    PROPN
# Times                 PROPN
# and                   CCONJ
# Washington            PROPN
# Post                  PROPN
# completely            ADV
# .                     PUNCT
# ========================================
# And international donors have given only half of the relief aid that Darfur needs , according to the local UN officials .
# Number of errors: 2
# And                   CCONJ
# international         ADJ
# donors                NOUN
# have                  AUX
# given                 VERB
# only                  ADV
# half                  NOUN
# of                    ADP
# the                   DET
# relief                NOUN
# aid                   NOUN
# that                  C: PRON          P: SCONJ        **** Frequent Error
# Darfur                PROPN
# needs                 C: VERB          P: NOUN         **** Error
# ,                     PUNCT
# according             VERB
# to                    ADP
# the                   DET
# local                 ADJ
# UN                    PROPN
# officials             NOUN
# .                     PUNCT
# ========================================
# So hear we are , two weeks later , after that dazzling PR display two weeks ago by Powell and Annan , and the situation on the ground in Darfur appears basically unchanged .
# Number of errors: 5
# So                    ADV
# hear                  C: ADV           P: VERB         **** Error
# we                    PRON
# are                   AUX
# ,                     PUNCT
# two                   NUM
# weeks                 NOUN
# later                 ADV
# ,                     PUNCT
# after                 ADP
# that                  C: DET           P: SCONJ        **** Frequent Error
# dazzling              C: ADJ           P: VERB         **** Error
# PR                    C: PROPN         P: NOUN         **** Error
# display               C: NOUN          P: VERB         **** Error
# two                   NUM
# weeks                 NOUN
# ago                   ADV
# by                    ADP
# Powell                PROPN
# and                   CCONJ
# Annan                 PROPN
# ,                     PUNCT
# and                   CCONJ
# the                   DET
# situation             NOUN
# on                    ADP
# the                   DET
# ground                NOUN
# in                    ADP
# Darfur                PROPN
# appears               VERB
# basically             ADV
# unchanged             ADJ
# .                     PUNCT
# ========================================
# It does n't change the company 's intrinsic worth , and as the article notes , the company might be added to a major index once the shares get more liquid .
# Number of errors: 6
# It                    PRON
# does                  AUX
# n't                   PART
# change                VERB
# the                   DET
# company               NOUN
# 's                    PART
# intrinsic             C: ADJ           P: NOUN         **** Error
# worth                 C: NOUN          P: ADJ          **** Error
# ,                     PUNCT
# and                   CCONJ
# as                    C: SCONJ         P: ADP          **** Frequent Error
# the                   DET
# article               NOUN
# notes                 C: VERB          P: NOUN         **** Error
# ,                     PUNCT
# the                   DET
# company               NOUN
# might                 AUX
# be                    AUX
# added                 VERB
# to                    ADP
# a                     DET
# major                 ADJ
# index                 NOUN
# once                  SCONJ
# the                   DET
# shares                NOUN
# get                   VERB
# more                  C: ADV           P: ADJ          **** Error
# liquid                C: ADJ           P: NOUN         **** Error
# .                     PUNCT
# ========================================
# He 's not giving 85 % away , he 's giving a number of shares each year that decrease in number at the rate of 5 % a year ( until gone ? ) .
# Number of errors: 4
# He                    PRON
# 's                    AUX
# not                   PART
# giving                VERB
# 85                    NUM
# %                     SYM
# away                  C: ADP           P: ADV          **** Error
# ,                     PUNCT
# he                    PRON
# 's                    AUX
# giving                VERB
# a                     DET
# number                NOUN
# of                    ADP
# shares                NOUN
# each                  DET
# year                  NOUN
# that                  C: PRON          P: SCONJ        **** Frequent Error
# decrease              C: VERB          P: NOUN         **** Error
# in                    ADP
# number                NOUN
# at                    ADP
# the                   DET
# rate                  NOUN
# of                    ADP
# 5                     NUM
# %                     SYM
# a                     DET
# year                  NOUN
# (                     PUNCT
# until                 SCONJ
# gone                  C: ADJ           P: VERB         **** Error
# ?                     PUNCT
# )                     PUNCT
# .                     PUNCT
# ========================================
# This acceptance of blatantly terrorist groups as legitimate freedom movements is a cancerous tumor on the United Nations and the media .
# Number of errors: 1
# This                  DET
# acceptance            NOUN
# of                    ADP
# blatantly             ADV
# terrorist             ADJ
# groups                NOUN
# as                    C: ADP           P: ADV          **** Frequent Error
# legitimate            ADJ
# freedom               NOUN
# movements             NOUN
# is                    AUX
# a                     DET
# cancerous             ADJ
# tumor                 NOUN
# on                    ADP
# the                   DET
# United                ADJ
# Nations               PROPN
# and                   CCONJ
# the                   DET
# media                 NOUN
# .                     PUNCT
# ========================================
# The decision to sidestep the obvious to satisfy the need to avoid confrontation does not bring peace , but only delays the eventual conflict as the predators of Hamas and Hezbollah exploit the inherent weakness of the internationals and the media .
# Number of errors: 1
# The                   DET
# decision              NOUN
# to                    PART
# sidestep              VERB
# the                   DET
# obvious               ADJ
# to                    PART
# satisfy               VERB
# the                   DET
# need                  NOUN
# to                    PART
# avoid                 VERB
# confrontation         NOUN
# does                  AUX
# not                   PART
# bring                 VERB
# peace                 NOUN
# ,                     PUNCT
# but                   CCONJ
# only                  ADV
# delays                VERB
# the                   DET
# eventual              ADJ
# conflict              NOUN
# as                    C: SCONJ         P: ADP          **** Frequent Error
# the                   DET
# predators             NOUN
# of                    ADP
# Hamas                 PROPN
# and                   CCONJ
# Hezbollah             PROPN
# exploit               VERB
# the                   DET
# inherent              ADJ
# weakness              NOUN
# of                    ADP
# the                   DET
# internationals        NOUN
# and                   CCONJ
# the                   DET
# media                 NOUN
# .                     PUNCT
# ========================================
# This is the organization that bombed our Marine barracks in 1983 , took Americans hostage throughout the 80's and now they should be considered a legitimate organization ?
# Number of errors: 1
# This                  PRON
# is                    AUX
# the                   DET
# organization          NOUN
# that                  C: PRON          P: SCONJ        **** Frequent Error
# bombed                VERB
# our                   PRON
# Marine                PROPN
# barracks              NOUN
# in                    ADP
# 1983                  NUM
# ,                     PUNCT
# took                  VERB
# Americans             PROPN
# hostage               NOUN
# throughout            ADP
# the                   DET
# 80's                  NOUN
# and                   CCONJ
# now                   ADV
# they                  PRON
# should                AUX
# be                    AUX
# considered            VERB
# a                     DET
# legitimate            ADJ
# organization          NOUN
# ?                     PUNCT
# ========================================
# In a communique , the AMS said that for Iraqis to take part with " raiding forces " in the assault on a city , the population of which is Muslim ( such as Fallujah ) would be considered the most mortal of mortal sins .
# Number of errors: 3
# In                    ADP
# a                     DET
# communique            NOUN
# ,                     PUNCT
# the                   DET
# AMS                   C: PROPN         P: NOUN         **** Error
# said                  VERB
# that                  SCONJ
# for                   C: SCONJ         P: ADP          **** Frequent Error
# Iraqis                PROPN
# to                    PART
# take                  VERB
# part                  NOUN
# with                  ADP
# "                     PUNCT
# raiding               VERB
# forces                NOUN
# "                     PUNCT
# in                    ADP
# the                   DET
# assault               NOUN
# on                    ADP
# a                     DET
# city                  NOUN
# ,                     PUNCT
# the                   DET
# population            NOUN
# of                    ADP
# which                 PRON
# is                    AUX
# Muslim                ADJ
# (                     PUNCT
# such                  ADJ
# as                    ADP
# Fallujah              PROPN
# )                     PUNCT
# would                 AUX
# be                    AUX
# considered            VERB
# the                   DET
# most                  C: ADV           P: ADJ          **** Error
# mortal                ADJ
# of                    ADP
# mortal                ADJ
# sins                  NOUN
# .                     PUNCT
# ========================================
# If the statement is true , it is a worrying sign that even the divided small radical guerrilla groups are being " picked up " by al - Qaeda .
# Number of errors: 3
# If                    SCONJ
# the                   DET
# statement             NOUN
# is                    AUX
# true                  ADJ
# ,                     PUNCT
# it                    PRON
# is                    AUX
# a                     DET
# worrying              C: ADJ           P: NOUN         **** Error
# sign                  NOUN
# that                  C: SCONJ         P: PRON         **** Frequent Error
# even                  ADV
# the                   DET
# divided               VERB
# small                 ADJ
# radical               ADJ
# guerrilla             NOUN
# groups                NOUN
# are                   AUX
# being                 AUX
# "                     PUNCT
# picked                VERB
# up                    C: ADV           P: ADP          **** Frequent Error
# "                     PUNCT
# by                    ADP
# al                    PROPN
# -                     PUNCT
# Qaeda                 PROPN
# .                     PUNCT
# ========================================
# They are probably especially oriented toward the Salafi school of modern Islamic thought , which has a Protestant - like emphasis on going back to the original practice of the early companions of the Prophet Muhammad .
# Number of errors: 4
# They                  PRON
# are                   AUX
# probably              ADV
# especially            ADV
# oriented              VERB
# toward                ADP
# the                   DET
# Salafi                C: ADJ           P: PROPN        **** Error
# school                NOUN
# of                    ADP
# modern                ADJ
# Islamic               ADJ
# thought               C: NOUN          P: VERB         **** Error
# ,                     PUNCT
# which                 PRON
# has                   VERB
# a                     DET
# Protestant            C: PROPN         P: ADJ          **** Error
# -                     PUNCT
# like                  C: ADJ           P: ADP          **** Frequent Error
# emphasis              NOUN
# on                    SCONJ
# going                 VERB
# back                  ADV
# to                    ADP
# the                   DET
# original              ADJ
# practice              NOUN
# of                    ADP
# the                   DET
# early                 ADJ
# companions            NOUN
# of                    ADP
# the                   DET
# Prophet               PROPN
# Muhammad              PROPN
# .                     PUNCT
# ========================================
# Monotheism and Holy War obviously does have a violent interpretation of Salafism , rather as the the leaders of the so - called German Peasant Rebellion among early Protestants did .
# Number of errors: 4
# Monotheism            PROPN
# and                   CCONJ
# Holy                  ADJ
# War                   PROPN
# obviously             ADV
# does                  AUX
# have                  VERB
# a                     DET
# violent               ADJ
# interpretation        NOUN
# of                    ADP
# Salafism              PROPN
# ,                     PUNCT
# rather                ADV
# as                    C: SCONJ         P: ADP          **** Frequent Error
# the                   DET
# the                   DET
# leaders               NOUN
# of                    ADP
# the                   DET
# so                    ADV
# -                     PUNCT
# called                VERB
# German                C: ADJ           P: PROPN        **** Error
# Peasant               C: PROPN         P: NOUN         **** Error
# Rebellion             PROPN
# among                 ADP
# early                 C: ADJ           P: ADV          **** Error
# Protestants           PROPN
# did                   AUX
# .                     PUNCT
# ========================================
# The consolidation of smaller local radical fundamentalist groups with al - Qaeda can also be seen in the case of the Fizazi group in Tangiers that morphed into the Moroccan Islamic Combatant Group , had members who met with September 11 ringleader Muhammad Atta , and ultimately was in part responsible for the Madrid train bombings .
# Number of errors: 5
# The                   DET
# consolidation         NOUN
# of                    ADP
# smaller               ADJ
# local                 C: ADJ           P: ADV          **** Error
# radical               ADJ
# fundamentalist        ADJ
# groups                NOUN
# with                  ADP
# al                    PROPN
# -                     PUNCT
# Qaeda                 PROPN
# can                   AUX
# also                  ADV
# be                    AUX
# seen                  VERB
# in                    ADP
# the                   DET
# case                  NOUN
# of                    ADP
# the                   DET
# Fizazi                PROPN
# group                 NOUN
# in                    ADP
# Tangiers              C: NOUN          P: PROPN        **** Error
# that                  C: PRON          P: SCONJ        **** Frequent Error
# morphed               VERB
# into                  C: SCONJ         P: ADP          **** Error
# the                   DET
# Moroccan              C: PROPN         P: ADJ          **** Error
# Islamic               ADJ
# Combatant             PROPN
# Group                 PROPN
# ,                     PUNCT
# had                   VERB
# members               NOUN
# who                   PRON
# met                   VERB
# with                  ADP
# September             PROPN
# 11                    NUM
# ringleader            NOUN
# Muhammad              PROPN
# Atta                  PROPN
# ,                     PUNCT
# and                   CCONJ
# ultimately            ADV
# was                   AUX
# in                    ADP
# part                  NOUN
# responsible           ADJ
# for                   ADP
# the                   DET
# Madrid                PROPN
# train                 NOUN
# bombings              NOUN
# .                     PUNCT
# ========================================
# If you believe crackpot theories instead of focusing on the reality -- that was an al - Qaeda operation mainly carried out by al - Gamaa al - Islamiyyah , an Egyptian terrorist component allied with Bin Laden -- then you will concentrate on the wrong threat .
# Number of errors: 1
# If                    SCONJ
# you                   PRON
# believe               VERB
# crackpot              NOUN
# theories              NOUN
# instead               ADV
# of                    SCONJ
# focusing              VERB
# on                    ADP
# the                   DET
# reality               NOUN
# --                    PUNCT
# that                  PRON
# was                   AUX
# an                    DET
# al                    PROPN
# -                     PUNCT
# Qaeda                 PROPN
# operation             NOUN
# mainly                ADV
# carried               VERB
# out                   C: ADP           P: ADV          **** Frequent Error
# by                    ADP
# al                    PROPN
# -                     PUNCT
# Gamaa                 PROPN
# al                    PROPN
# -                     PUNCT
# Islamiyyah            PROPN
# ,                     PUNCT
# an                    DET
# Egyptian              ADJ
# terrorist             NOUN
# component             NOUN
# allied                VERB
# with                  ADP
# Bin                   PROPN
# Laden                 PROPN
# --                    PUNCT
# then                  ADV
# you                   PRON
# will                  AUX
# concentrate           VERB
# on                    ADP
# the                   DET
# wrong                 ADJ
# threat                NOUN
# .                     PUNCT
# ========================================
# The Pentagon did not even have a plan for dealing with Afghanistan or al - Qaeda that it could pull off the shelf , according to Bob Woodward .
# Number of errors: 1
# The                   DET
# Pentagon              PROPN
# did                   AUX
# not                   PART
# even                  ADV
# have                  VERB
# a                     DET
# plan                  NOUN
# for                   SCONJ
# dealing               VERB
# with                  ADP
# Afghanistan           PROPN
# or                    CCONJ
# al                    PROPN
# -                     PUNCT
# Qaeda                 PROPN
# that                  C: PRON          P: SCONJ        **** Frequent Error
# it                    PRON
# could                 AUX
# pull                  VERB
# off                   ADP
# the                   DET
# shelf                 NOUN
# ,                     PUNCT
# according             VERB
# to                    ADP
# Bob                   PROPN
# Woodward              PROPN
# .                     PUNCT
# ========================================
# Dick could never thereafter get any real cooperation from the cabinet officers , who outranked him , and he could not convince them to go to battle stations in the summer of 2001 when George Tenet 's hair was " on fire " about the excited chatter the CIA was picking up from radical Islamist terrorists .
# Number of errors: 2
# Dick                  C: PROPN         P: ADJ          **** Error
# could                 AUX
# never                 ADV
# thereafter            ADV
# get                   VERB
# any                   DET
# real                  ADJ
# cooperation           NOUN
# from                  ADP
# the                   DET
# cabinet               NOUN
# officers              NOUN
# ,                     PUNCT
# who                   PRON
# outranked             VERB
# him                   PRON
# ,                     PUNCT
# and                   CCONJ
# he                    PRON
# could                 AUX
# not                   PART
# convince              VERB
# them                  PRON
# to                    PART
# go                    VERB
# to                    ADP
# battle                NOUN
# stations              NOUN
# in                    ADP
# the                   DET
# summer                NOUN
# of                    ADP
# 2001                  NUM
# when                  ADV
# George                PROPN
# Tenet                 PROPN
# 's                    PART
# hair                  NOUN
# was                   AUX
# "                     PUNCT
# on                    ADP
# fire                  NOUN
# "                     PUNCT
# about                 ADP
# the                   DET
# excited               ADJ
# chatter               NOUN
# the                   DET
# CIA                   PROPN
# was                   AUX
# picking               VERB
# up                    C: ADP           P: ADV          **** Frequent Error
# from                  ADP
# radical               ADJ
# Islamist              PROPN
# terrorists            NOUN
# .                     PUNCT
# ========================================
# Clinton had worked out a deal with Pakistani Prime Minister Nawaz Sharif in summer of 1999 that would have allowed the US to send a Special Ops team in after Bin Laden in Qandahar , based from Pakistan .
# Number of errors: 2
# Clinton               PROPN
# had                   AUX
# worked                VERB
# out                   ADP
# a                     DET
# deal                  NOUN
# with                  ADP
# Pakistani             ADJ
# Prime                 ADJ
# Minister              PROPN
# Nawaz                 PROPN
# Sharif                PROPN
# in                    ADP
# summer                NOUN
# of                    ADP
# 1999                  NUM
# that                  PRON
# would                 AUX
# have                  C: AUX           P: VERB         **** Error
# allowed               VERB
# the                   DET
# US                    PROPN
# to                    PART
# send                  VERB
# a                     DET
# Special               ADJ
# Ops                   NOUN
# team                  NOUN
# in                    C: ADV           P: ADP          **** Frequent Error
# after                 ADP
# Bin                   PROPN
# Laden                 PROPN
# in                    ADP
# Qandahar              PROPN
# ,                     PUNCT
# based                 VERB
# from                  ADP
# Pakistan              PROPN
# .                     PUNCT
# ========================================
# I presume you need the Pakistan base for rescue operations in case anything went wrong .
# Number of errors: 2
# I                     PRON
# presume               VERB
# you                   PRON
# need                  VERB
# the                   DET
# Pakistan              PROPN
# base                  NOUN
# for                   ADP
# rescue                NOUN
# operations            NOUN
# in                    C: SCONJ         P: ADP          **** Frequent Error
# case                  NOUN
# anything              PRON
# went                  VERB
# wrong                 C: ADJ           P: ADV          **** Error
# .                     PUNCT
# ========================================
# Musharraf told Clinton he could n't use Pakistani soil or air space to send the team in against Bin Laden .
# Number of errors: 1
# Musharraf             PROPN
# told                  VERB
# Clinton               PROPN
# he                    PRON
# could                 AUX
# n't                   PART
# use                   VERB
# Pakistani             ADJ
# soil                  NOUN
# or                    CCONJ
# air                   NOUN
# space                 NOUN
# to                    PART
# send                  VERB
# the                   DET
# team                  NOUN
# in                    C: ADV           P: ADP          **** Frequent Error
# against               ADP
# Bin                   PROPN
# Laden                 PROPN
# .                     PUNCT
# ========================================
# Of course , you could just go in by main force .
# Number of errors: 1
# Of                    ADP
# course                NOUN
# ,                     PUNCT
# you                   PRON
# could                 AUX
# just                  ADV
# go                    VERB
# in                    C: ADV           P: ADP          **** Frequent Error
# by                    ADP
# main                  ADJ
# force                 NOUN
# .                     PUNCT
# ========================================
# that is how i want you to refer to me as " the king "
# Number of errors: 1
# that                  PRON
# is                    AUX
# how                   ADV
# i                     PRON
# want                  VERB
# you                   PRON
# to                    PART
# refer                 VERB
# to                    ADP
# me                    PRON
# as                    C: ADP           P: SCONJ        **** Frequent Error
# "                     PUNCT
# the                   DET
# king                  NOUN
# "                     PUNCT
# ========================================
# like what ?
# Number of errors: 1
# like                  C: ADP           P: INTJ         **** Frequent Error
# what                  PRON
# ?                     PUNCT
# ========================================
# i was thinking somewhere that requires a jacket , like tony 's .
# Number of errors: 3
# i                     PRON
# was                   AUX
# thinking              VERB
# somewhere             ADV
# that                  C: PRON          P: SCONJ        **** Frequent Error
# requires              VERB
# a                     DET
# jacket                NOUN
# ,                     PUNCT
# like                  C: ADP           P: VERB         **** Frequent Error
# tony                  C: PROPN         P: NOUN         **** Error
# 's                    PART
# .                     PUNCT
# ========================================
# someplace that is like $ 30 an entree .
# Number of errors: 2
# someplace             C: ADV           P: NOUN         **** Error
# that                  PRON
# is                    AUX
# like                  C: ADP           P: VERB         **** Frequent Error
# $                     SYM
# 30                    NUM
# an                    DET
# entree                NOUN
# .                     PUNCT
# ========================================
# i do n't even like a&m , i would n't bet on them .
# Number of errors: 3
# i                     PRON
# do                    AUX
# n't                   PART
# even                  ADV
# like                  C: VERB          P: ADP          **** Frequent Error
# a&m                   C: PROPN         P: NOUN         **** Error
# ,                     PUNCT
# i                     PRON
# would                 AUX
# n't                   PART
# bet                   VERB
# on                    C: ADP           P: SCONJ        **** Frequent Error
# them                  PRON
# .                     PUNCT
# ========================================
# I heard that more may be going up for sale in the next month or do .
# Number of errors: 2
# I                     PRON
# heard                 VERB
# that                  SCONJ
# more                  ADJ
# may                   AUX
# be                    AUX
# going                 VERB
# up                    C: ADJ           P: ADV          **** Frequent Error
# for                   ADP
# sale                  NOUN
# in                    ADP
# the                   DET
# next                  ADJ
# month                 NOUN
# or                    CCONJ
# do                    C: ADV           P: AUX          **** Error
# .                     PUNCT
# ========================================
# This was a risk that we had but we did have assurances from Phillips regarding performance .
# Number of errors: 1
# This                  PRON
# was                   AUX
# a                     DET
# risk                  NOUN
# that                  C: PRON          P: SCONJ        **** Frequent Error
# we                    PRON
# had                   VERB
# but                   CCONJ
# we                    PRON
# did                   AUX
# have                  VERB
# assurances            NOUN
# from                  ADP
# Phillips              PROPN
# regarding             VERB
# performance           NOUN
# .                     PUNCT
# ========================================
# Have you seen the materials from the press conference that he launched today ?
# Number of errors: 1
# Have                  AUX
# you                   PRON
# seen                  VERB
# the                   DET
# materials             NOUN
# from                  ADP
# the                   DET
# press                 NOUN
# conference            NOUN
# that                  C: PRON          P: SCONJ        **** Frequent Error
# he                    PRON
# launched              VERB
# today                 NOUN
# ?                     PUNCT
# ========================================
# why is enron blowing up ?
# Number of errors: 1
# why                   ADV
# is                    AUX
# enron                 PROPN
# blowing               VERB
# up                    C: ADP           P: NOUN         **** Frequent Error
# ?                     PUNCT
# ========================================
# enron is blowing up .
# Number of errors: 1
# enron                 PROPN
# is                    AUX
# blowing               VERB
# up                    C: ADP           P: NOUN         **** Frequent Error
# .                     PUNCT
# ========================================
# In addition , is there someone who could consider the correlation between US CPI and the $ / euro exchange rate .
# Number of errors: 4
# In                    ADP
# addition              NOUN
# ,                     PUNCT
# is                    C: VERB          P: AUX          **** Error
# there                 PRON
# someone               PRON
# who                   PRON
# could                 AUX
# consider              VERB
# the                   DET
# correlation           NOUN
# between               ADP
# US                    PROPN
# CPI                   NOUN
# and                   CCONJ
# the                   DET
# $                     C: NOUN          P: SYM          **** Error
# /                     C: PUNCT         P: SYM          **** Frequent Error
# euro                  C: NOUN          P: PROPN        **** Error
# exchange              NOUN
# rate                  NOUN
# .                     PUNCT
# ========================================
# The goal is for him to move on with his life and for us to move on as well .
# Number of errors: 2
# The                   DET
# goal                  NOUN
# is                    AUX
# ...
# of                    ADP
# dreams                NOUN
# .                     PUNCT
# "                     PUNCT
# ========================================
# Wiki Media Foundation , the group behind the Wikipedia online encyclopedia project , said Friday that search giant Google has volunteered to host some of its content on company servers .
# Number of errors: 3
# Wiki                  PROPN
# Media                 C: PROPN         P: NOUN         **** Error
# Foundation            PROPN
# ,                     PUNCT
# the                   DET
# group                 NOUN
# behind                ADP
# the                   DET
# Wikipedia             PROPN
# online                ADJ
# encyclopedia          NOUN
# project               NOUN
# ,                     PUNCT
# said                  VERB
# Friday                PROPN
# that                  C: SCONJ         P: DET          **** Frequent Error
# search                C: NOUN          P: VERB         **** Error
# giant                 NOUN
# Google                PROPN
# has                   AUX
# volunteered           VERB
# to                    PART
# host                  VERB
# some                  DET
# of                    ADP
# its                   PRON
# content               NOUN
# on                    ADP
# company               NOUN
# servers               NOUN
# .                     PUNCT
# ========================================
# But it looks like Google is n't opening it's mouth about the reason behind the offer as Linux News reports :
# Number of errors: 2
# But                   CCONJ
# it                    PRON
# looks                 VERB
# like                  SCONJ
# Google                PROPN
# is                    AUX
# n't                   PART
# opening               VERB
# it's                  PRON
# mouth                 NOUN
# about                 ADP
# the                   DET
# reason                NOUN
# behind                ADP
# the                   DET
# offer                 NOUN
# as                    C: SCONJ         P: ADP          **** Frequent Error
# Linux                 PROPN
# News                  PROPN
# reports               C: VERB          P: NOUN         **** Error
# :                     PUNCT
# ========================================
# " While we do n't have anything specific to announce today , Google and the Wikimedia Foundation are collaboratively evaluating creative ways to support Wikipedia.org and its community . "
# Number of errors: 1
# "                     PUNCT
# While                 SCONJ
# we                    PRON
# do                    AUX
# n't                   PART
# have                  VERB
# anything              PRON
# specific              ADJ
# to                    C: PART          P: ADP          **** Frequent Error
# announce              VERB
# today                 NOUN
# ,                     PUNCT
# Google                PROPN
# and                   CCONJ
# the                   DET
# Wikimedia             PROPN
# Foundation            PROPN
# are                   AUX
# collaboratively       ADV
# evaluating            VERB
# creative              ADJ
# ways                  NOUN
# to                    PART
# support               VERB
# Wikipedia.org         PROPN
# and                   CCONJ
# its                   PRON
# community             NOUN
# .                     PUNCT
# "                     PUNCT
# ========================================
# It would be great if the person from CHANT who started this page would put up a short description of the campaign and a list to this group page on the Action Network site .
# Number of errors: 2
# It                    PRON
# would                 AUX
# be                    AUX
# great                 ADJ
# if                    SCONJ
# the                   DET
# person                NOUN
# from                  ADP
# CHANT                 PROPN
# who                   PRON
# started               VERB
# this                  DET
# page                  NOUN
# would                 AUX
# put                   VERB
# up                    C: ADV           P: ADP          **** Frequent Error
# a                     DET
# short                 ADJ
# description           NOUN
# of                    ADP
# the                   DET
# campaign              NOUN
# and                   CCONJ
# a                     DET
# list                  NOUN
# to                    ADP
# this                  DET
# group                 NOUN
# page                  NOUN
# on                    ADP
# the                   DET
# Action                PROPN
# Network               C: PROPN         P: NOUN         **** Error
# site                  NOUN
# .                     PUNCT
# ========================================
# One little boy stands up and offers that , " if my best friend who lives next door was playing in the street when a car came along and killed him , that would be a tragedy " .
# Number of errors: 3
# One                   NUM
# little                ADJ
# boy                   NOUN
# stands                VERB
# up                    C: ADV           P: ADP          **** Frequent Error
# and                   CCONJ
# offers                C: VERB          P: NOUN         **** Error
# that                  C: SCONJ         P: PRON         **** Frequent Error
# ,                     PUNCT
# "                     PUNCT
# if                    SCONJ
# my                    PRON
# best                  ADJ
# friend                NOUN
# who                   PRON
# lives                 VERB
# next                  ADJ
# door                  NOUN
# was                   AUX
# playing               VERB
# in                    ADP
# the                   DET
# street                NOUN
# when                  ADV
# a                     DET
# car                   NOUN
# came                  VERB
# along                 ADV
# and                   CCONJ
# killed                VERB
# him                   PRON
# ,                     PUNCT
# that                  PRON
# would                 AUX
# be                    AUX
# a                     DET
# tragedy               NOUN
# "                     PUNCT
# .                     PUNCT
# ========================================
# In a timid voice , he says : " If an airplane carrying Winston Peters was blown up by a bomb , THAT would be a tragedy " .
# Number of errors: 3
# In                    ADP
# a                     DET
# timid                 C: ADJ           P: NOUN         **** Error
# voice                 C: NOUN          P: PROPN        **** Error
# ,                     PUNCT
# he                    PRON
# says                  VERB
# :                     PUNCT
# "                     PUNCT
# If                    SCONJ
# an                    DET
# airplane              NOUN
# carrying              VERB
# Winston               PROPN
# Peters                PROPN
# was                   AUX
# blown                 VERB
# up                    C: ADP           P: ADV          **** Frequent Error
# by                    ADP
# a                     DET
# bomb                  NOUN
# ,                     PUNCT
# THAT                  PRON
# would                 AUX
# be                    AUX
# a                     DET
# tragedy               NOUN
# "                     PUNCT
# .                     PUNCT
# ========================================
# It looks like The Lunar Transportation Systems , Inc. is visualizing a " space highway " going from the moon to Earth ( and back again ) .
# Number of errors: 2
# It                    PRON
# looks                 VERB
# like                  C: SCONJ         P: ADP          **** Frequent Error
# The                   DET
# Lunar                 ADJ
# Transportation        PROPN
# Systems               PROPN
# ,                     PUNCT
# Inc.                  PROPN
# is                    AUX
# visualizing           VERB
# a                     DET
# "                     PUNCT
# space                 NOUN
# highway               NOUN
# "                     PUNCT
# going                 VERB
# from                  ADP
# the                   DET
# moon                  C: PROPN         P: NOUN         **** Error
# to                    ADP
# Earth                 PROPN
# (                     PUNCT
# and                   CCONJ
# back                  ADV
# again                 ADV
# )                     PUNCT
# .                     PUNCT
# ========================================
# They want to use LTS to tie into NASA 's vision for Space Exploration , and seem pleased that the White House is moving in that direction .
# Number of errors: 3
# They                  PRON
# want                  VERB
# to                    PART
# use                   VERB
# LTS                   PROPN
# to                    C: PART          P: ADP          **** Frequent Error
# tie                   VERB
# into                  ADP
# NASA                  PROPN
# 's                    PART
# vision                NOUN
# for                   ADP
# Space                 C: NOUN          P: PROPN        **** Error
# Exploration           C: NOUN          P: PROPN        **** Error
# ,                     PUNCT
# and                   CCONJ
# seem                  VERB
# pleased               ADJ
# that                  SCONJ
# the                   DET
# White                 ADJ
# House                 PROPN
# is                    AUX
# moving                VERB
# in                    ADP
# that                  DET
# direction             NOUN
# .                     PUNCT
# ========================================
# " We are so excited that the White House and the recent new government space policy underscores the need to involve the private sector in assisting NASA develop its plans for the new Vision for Space Exploration , " said Walter Kistler , LTS co-founder and Chairman .
# Number of errors: 4
# "                     PUNCT
# We                    PRON
# are                   AUX
# so                    ADV
# excited               ADJ
# that                  SCONJ
# the                   DET
# White                 ADJ
# House                 PROPN
# and                   CCONJ
# the                   DET
# recent                ADJ
# new                   ADJ
# government            NOUN
# space                 NOUN
# policy                NOUN
# underscores           VERB
# the                   DET
# need                  NOUN
# to                    PART
# involve               VERB
# the                   DET
# private               ADJ
# sector                NOUN
# in                    C: SCONJ         P: ADP          **** Frequent Error
# assisting             VERB
# NASA                  PROPN
# develop               VERB
# its                   PRON
# plans                 NOUN
# for                   ADP
# the                   DET
# new                   ADJ
# Vision                NOUN
# for                   ADP
# Space                 C: NOUN          P: PROPN        **** Error
# Exploration           C: NOUN          P: PROPN        **** Error
# ,                     PUNCT
# "                     PUNCT
# said                  VERB
# Walter                PROPN
# Kistler               PROPN
# ,                     PUNCT
# LTS                   PROPN
# co-founder            NOUN
# and                   CCONJ
# Chairman              C: NOUN          P: PROPN        **** Error
# .                     PUNCT
# ========================================
# With their proposal of a " Earth - Moon " highway , it looks like space tourism may become a reality sooner than we think .
# Number of errors: 2
# With                  C: ADP           P: SCONJ        **** Error
# their                 PRON
# proposal              NOUN
# of                    ADP
# a                     DET
# "                     PUNCT
# Earth                 PROPN
# -                     PUNCT
# Moon                  PROPN
# "                     PUNCT
# highway               NOUN
# ,                     PUNCT
# it                    PRON
# looks                 VERB
# like                  C: SCONJ         P: ADJ          **** Frequent Error
# space                 NOUN
# tourism               NOUN
# may                   AUX
# become                VERB
# a                     DET
# reality               NOUN
# sooner                ADV
# than                  SCONJ
# we                    PRON
# think                 VERB
# .                     PUNCT
# ========================================
# Lunar landers and other gear needed for extended visits to the moon will be lofted by gargantuan launchers as big as the Apollo - era Saturn 5 , the most powerful rockets ever flown .
# Number of errors: 3
# Lunar                 ADJ
# landers               NOUN
# and                   CCONJ
# other                 ADJ
# gear                  NOUN
# needed                VERB
# for                   ADP
# extended              ADJ
# visits                NOUN
# to                    ADP
# the                   DET
# moon                  C: PROPN         P: NOUN         **** Error
# will                  AUX
# be                    AUX
# lofted                VERB
# by                    ADP
# gargantuan            C: ADJ           P: NOUN         **** Error
# launchers             NOUN
# as                    ADV
# big                   ADJ
# as                    C: ADP           P: SCONJ        **** Frequent Error
# the                   DET
# Apollo                PROPN
# -                     PUNCT
# era                   NOUN
# Saturn                PROPN
# 5                     NUM
# ,                     PUNCT
# the                   DET
# most                  ADV
# powerful              ADJ
# rockets               NOUN
# ever                  ADV
# flown                 VERB
# .                     PUNCT
# ========================================
# Showing 100 of the sentences containing frequently misclassified tokens.
# Total sentences shown: 100

# %% [markdown]
# 2. Provide a possible reason why these errors are made by the tagger based on your understanding of the knowledge needed to correctly tag these tokens.
#
#
#
#     The most frequently misclassified tokens (that, as, to, like, out, for, up, /, in, on)
#     share common characteristics that challenge our tagger:
#
#     1. Grammatical Ambiguity: Most of these tokens can function in multiple grammatical roles
#     - "that": Can be PRON, SCONJ, or DET depending on context
#     - "like": Functions as VERB, ADP, or ADJ in different usages
#
#     2. Feature Limitations: Our model's feature extraction has limitations
#     - Limited context window (only previous/next word)
#     - No access to full syntactic structure
#     - Relies on surface features rather than deeper linguistic patterns
#
#     3. Preposition/Particle Confusion: Many errors involve preposition/particle/adverb confusion
#     - "up"/"out": Confused betwåeen ADV and ADP roles (especially in phrasal verbs)
#     - "to": Confused between infinitive marker (PART) and preposition (ADP)
#
#     4. Training Data Issues: Possibly insufficient examples of ambiguous uses

# %% [markdown]
# 3. 3. Based on this error analysis, invent five sentences that are badly tagged. Explain what is your method to create these hard examples.
#
#
#     1. "That that that boy mentioned is not what I meant."
#
#     - This uses "that" three different ways in a row - pretty confusing even for humans!
#     - The first is a determiner, the second is a relative pronoun, and the third is a complementizer
#
#
#     2. "I like people who like to run like the wind up the hill."
#
#     - Here "like" appears as a verb, then another verb, then as a preposition
#     - Also included "up" which is often misclassified
#
#
#     3. "For for-profit companies, as well as non-profits, operating for the public good is essential."
#
#    -  The word "for" appears in three different roles here
#     - Also included "as" which was another frequent error
#
#
#     4. "The plan that I came up with was to go to the store for supplies."
#
#     - I packed in several troublemakers here: "that," "up," "to" (twice), and "for"
#     - The tagger would likely confuse which "to" is an infinitive marker vs. a preposition
#
#
#     5. "Out of all options, we picked one that stands out as particularly innovative."
#
#     - Used "out" in two different ways (as part of "out of" and in "stands out")
#     - Included "that" and "as" which were top error sources
